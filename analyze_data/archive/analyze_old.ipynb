# %% [markdown]
# # Analyser les données
# Si lors de la partie du scraping, on se contentait uniquement de récupérer la données, ici l'objectif sera de la traiter pour la rendre accessible et ainsi faire des analyses dessus. Car en l'état un tweet est très peu exploitable, de la même manière qu'on ne veut pas de tout les tweets récoltés, mais seulement une portion.

# %% [markdown]
# ## Mise en place

# %%
import pandas as pd
import uuid
import requests
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk import ngrams
import unicodedata
import re
from collections import Counter
import string
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gabriel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
plt.rcParams.update({
    "axes.spines.top": False,    # Désactiver la bordure supérieure
    "axes.spines.right": False, # Désactiver la bordure droite
    "axes.spines.left": False,  # Désactiver la bordure gauche
})
sns.set(style="white")  # Supprime le fond gris de base

# %%
def concat_all_parts(*args):
    dataframes = []
    for file in args:
        df = pd.read_csv(file)
        df['content'] = df['content'].astype(str)
        dataframes.append(df)
    combined_df = pd.concat(dataframes, ignore_index=True)
    return combined_df

# Exemple d'utilisation
df_f = concat_all_parts('../scraper/data/part1.csv', '../scraper/data/part2.csv', '../scraper/data/part3.csv')
df_f.reset_index(drop=True, inplace=True)

print(df_f.shape)
df_f.drop_duplicates(subset=['content', 'time_posted'], inplace=True)
print(df_f.shape)
# Out:
# (2725, 9)
# (2716, 9)

# %% [markdown]
# Ici on créer un dictionnaire qui, pour chacune des gares de la ligne du RER A associe toutes les manières de l'écrire possible. Par exemple Boissy-Saint-Léger peut aussi être écrit comme Boissy-St-Léger, ce sont 2 orthographes différentes pour une même ; on répète ce processus pour toutes les gares.
# Ce dictionnaire permettra de facilement trouver la gare mentionnée dans un tweet.

# %%
stations_rer_a_constant_dict = {
    "Achères Grand Cormier":["Achères Grand Cormier"],
    "Achères Ville" : ["Achères Ville"],
    "Auber" : ["Auber"],
    "Boissy-Saint-Léger" : ["Boissy-Saint-Léger", "Boissy-St-Léger", "Boissy", "Poissy Saint Léger"],
    "Bry-sur-Marne": ["Bry-sur-Marne"],
    "Bussy-Saint-Georges": ["Bussy-Saint-Georges", "Bussy-St-Georges"],
    "Cergy le Haut" : ["Cergy le Haut", "Cergy"],
    "Cergy Préfecture" : ["Cergy Préfecture"],
    "Cergy Saint-Christophe" : ["Cergy Saint-Christophe", "Cergy St-Christophe"],
    "Champigny": ["Champigny"],
    "Charles de Gaulle-Etoile" : ["Charles de Gaulle-Etoile"],
    "Châtelet les Halles" : ["Châtelet les Halles"],
    "Chatou-Croissy" : ["Chatou-Croissy"],
    "Conflans Fin d'Oise" : ["Conflans Fin d'Oise", "Conflans – Fin d’Oise"],
    "Fontenay-sous-Bois" : ["Fontenay-sous-Bois", "Fontenay"],
    "Gare de Lyon" : ["Gare de Lyon"],
    "Houilles-Carrières-sur-Seine" : ["Houilles-Carrières-sur-Seine", "Houilles"],
    "Joinville-le-Pont" : ["Joinville-le-Pont"],
    "La Défense" : ["La Défense", "Défense"],
    "La Varenne-Chennevières" :["La Varenne-Chennevières", "Varenne-Chennevières", "Varennes Chennevieres"],
    "Parc de Saint-Maur" : ["Parc de Saint-Maur", "Parc de St-Maur", "Parc Saint-Maur", "Parc St-Maur"],
    "Le Vésinet-Centre" : ["Le Vésinet-Centre", "Vésinet-Centre"],
    "Le Vésinet-Le Pecq" : ["Le Vésinet-Le Pecq", "Vésinet-Le Pecq"],
    "Lognes": ["Lognes"],
    "Maisons-Laffitte" : ["Maisons-Laffitte", "Maison-Laffitte", "Maisons-Laffite", "Maison-Laffite"],
    "Marne-la-Vallée-Chessy" : ["Marne-la-Vallée-Chessy", "MLV-Chessy", "Marne la Vallée", "Chessy"],
    "Nanterre Préfecture" : ['Nanterre Préfecture', "Nantere Pref", "Nanterre-P"],
    "Nanterre Université" : ["Nanterre Université"],
    "Nanterre Ville" : ["Nanterre Ville"],
    "Nation" : ["Nation"],
    "Neuilly-Plaisance" : ["Neuilly-Plaisance"],
    "Neuville Université": ["Neuville Université"],
    "Nogent-sur-Marne" : ["Nogent-sur-Marne"],
    "Noisiel" : ["Noisiel"],
    "Noisy-Champs" : ["Noisy-Champs"],
    "Noisy-le-Grand-Mont d'Est" : ["Noisy-le-Grand-Mont d'Est", "Noisy-le-Grand"],
    "Poissy" : ["Poissy"],
    "Rueil-Malmaison" : ["Rueil-Malmaison"],
    "Saint-Germain-en-Laye" : ["Saint-Germain-en-Laye", "St-Germain-En-Laye", "St Germain", "Saint Germain"],
    "Saint-Maur-Créteil" : ["Saint-Maur-Créteil", "St-Maur-Créteil"],
    "Sartrouville" : ["Sartrouville"],
    "Sucy-Bonneuil" : ["Sucy-Bonneuil"],
    "Torcy" : ["Torcy"],
    "Val d'Europe" : ["Val d'Europe"],
    "Val de Fontenay" : ["Val de Fontenay"],
    "Vincennes" : ["Vincennes"],
}

# %% [markdown]
# ## Nettoyage
# Après avoir importé les données et créé un premier référentiel, il est temps de nettoyer les données.
# Les étapes de nettoyage seront décrite au fur et à mesure.

# %% [markdown]
# ### Création d'une fonction
# Pour simplifier le processus, une fonction est créée rassemblant les étapes principales du nettoyage de données. On y retrouve la mise en minuscule, la normalisation en remplacant les caractères accentués, retirer les chiffres ou espaces supllémentaires...
# Cette première fonction permettra de mettre les données à un même stade.

# %%
def clean_text(text):
    text = text.lower()
    text = text.replace('–', '-')
    text = text.replace('\n', ' ')
    text = unicodedata.normalize('NFKD', text).encode('ASCII', 'ignore').decode("utf-8")
    text = re.sub(r'[^\w\s]',' ',text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'\s{2,}', ' ', text)
    return text

# %% [markdown]
# ### Nettoyer le réferentiel
# Comme le référentiel des gares n'est pas totalement propre, il passe par la fonction de nettoyage, de cette manière lorsqu'on nettoiera les données de tweet, les différentes orthogrpahe de gares auront les mêmes caractéristiques.

# %%
stations_rer_a_cleaned_dict = stations_rer_a_constant_dict.copy()
for key, value in stations_rer_a_cleaned_dict.items():
    stations_rer_a_cleaned_dict[key] = [clean_text(station) for station in value]
df_f['content_cleaned'] = df_f['content'].apply(clean_text)

# %% [markdown]
# ### Détecter les gares
# L'objectif du référentiel est de pouvoir retrouver les gares mentionnées dans les tweets. Eh bien, c'est ce qui va être fait ici !
# Comme plusieurs gares peuvent apparaître dans un tweet, il est nécessaire d'itérer sur toutes les gares du référentiel et de noter la clé du dictionnaire associés comme occurrence.
# Le problème avec ça est que dans le cas où la gare "Boissy Saint Léger" sera mentionnée, comme dans ses appellations il y a "Boissy" et "Boissy Saint Léger" on peut voir qu'une possibilité d'occurrence est contenue dans l'autre. C'est à dire que pour cette gare on comptera 2 occurrences.
#
# Pour éviter ce problème, la solution employée (qui n'est pas la plus optimale) et de vérifier le contenu du texte à l'aide d'une fénetre s'étendant d'un caractère vers la droite tant que rien n'est trouvé. Si une gare est trouvée dans cette fenêtre, on note la gare, et la nouvelle fenêtre de recherche commencera à la fin de la gare trouvée. De cette manière on évite d'itérer sur une gare déjà trouvée.

# %% [markdown]
# #### Tester la fonction de fenêtrage

# %%
current_text = "les trains actuellement entre bussy saint georges et marne la vallee chessy et en direction de marne la vallee chessy stationnent en raison d une panne electrique a marne la vallee chessy rera"

cursor_deb = 0
cursor_end = 1


def find_gare(text):
    for gare_key in stations_rer_a_cleaned_dict.keys():
        for gare2 in stations_rer_a_cleaned_dict[gare_key]:
            if gare2 in text:
                return gare2, gare_key
    return None, None


def find_max_len_gare_from_key(gare_key, gare_matched, text, cursor_deb, cursor_end):
    current_len = len(gare_matched)

    temp_list = stations_rer_a_cleaned_dict[gare_key].copy()
    temp_list.sort(key=len, reverse=True)
    max_len_gare = temp_list[0]
    diff_len = len(max_len_gare) - current_len

    cursor_end2 = cursor_end + diff_len

    new_text = text[cursor_deb:cursor_end2]
    for gare in temp_list:
        if gare in new_text:
            return gare, cursor_end2
                

while cursor_end < len(current_text):

    ## Find gare between cursor_deb and cursor_end
    gare, gare_key = find_gare(current_text[cursor_deb:cursor_end])

    if gare is None:
        cursor_end += 1
    else:
        gare, cursor_end = find_max_len_gare_from_key(gare_key, gare, current_text, cursor_deb, cursor_end)
        print(gare)
        cursor_deb = cursor_end
        cursor_end = cursor_deb + 1
# Out:
# bussy saint georges
# marne la vallee chessy
# marne la vallee chessy
# marne la vallee chessy

# %% [markdown]
# #### Application de la fonction de fenêtrage

# %%
for index, row in df_f.iterrows():
    current_text = row['content_cleaned']
    cursor_deb = 0
    cursor_end = 1

    gare_detected = []

    while cursor_end < len(current_text):

        gare, gare_key = find_gare(current_text[cursor_deb:cursor_end])

        if gare is None:
            cursor_end += 1
        else:
            gare, cursor_end = find_max_len_gare_from_key(gare_key, gare, current_text, cursor_deb, cursor_end)
            gare_detected.append(gare_key)
            cursor_deb = cursor_end
            cursor_end = cursor_deb + 1 

    df_f.loc[index, 'gare_detected'] = ",".join(gare_detected)

# %%
df_f['nb_gare_detected'] = df_f['gare_detected'].apply(lambda x: len(x.split(',')))
df_f.groupby(['tweet_type', 'nb_gare_detected']).size()
# Out:
# tweet_type  nb_gare_detected
# Normal      1                   148
#             2                   590
#             3                   274
#             4                    67
#             5                    23
#             6                     4
#             7                     7
# Réponse     1                   382
#             2                   625
#             3                   366
#             4                   155
#             5                    60
#             6                    14
#             7                     1
# dtype: int64

# %%
"""
for index, row in df_f.iterrows():
    tweet_text = row['content_cleaned']
    tweet_len = len(tweet_text)

    cursor_begin = 0
    cursor_end = 0

    gare_detec = []

    while cursor_end <= tweet_len:
        current_text = tweet_text[cursor_begin:cursor_end]

        for gare_key in stations_rer_a_cleaned_dict.keys():

            gare = ""
            # marne la vallee chessy ne matche pas alors que, marne la vallee et chessy matchent
            for gare2 in stations_rer_a_cleaned_dict[gare_key]:
                if gare2 in current_text:
                    gare = gare2
                    if tweet_text == "les trains actuellement entre bussy saint georges et marne la vallee chessy et en direction de marne la vallee chessy stationnent en raison d une panne electrique a marne la vallee chessy rera":
                        print(gare)
                    break

            if gare == "":
                continue
                    
            temp_list = stations_rer_a_cleaned_dict[gare_key].copy()
            temp_list.sort(key=len, reverse=True)
            
            max_len_gare = len(temp_list[0])
            diff_len = max_len_gare - len(gare)

            best_gare_name_len = 0
            best_gare_name = ""
            for gare2 in stations_rer_a_cleaned_dict[gare_key]:
                if gare2 in tweet_text[cursor_begin:cursor_end+diff_len]:
                    if len(gare2) > best_gare_name_len:
                        best_gare_name_len = len(gare2)
                        best_gare_name = gare2

                
            gare_detec.append(gare_key)
            cursor_begin = cursor_end+(max_len_gare-len(best_gare_name))
                    

        cursor_end += 1
    df_f.loc[index, 'gare_detected'] = ",".join(gare_detec)
"""
# Out:
# bussy saint georges
# marne la vallee
# chessy
# marne la vallee
# chessy
# marne la vallee
# chessy

# %%
"""df_f['gare_detected'] = ""
for index, row in df_f.iterrows():
    gare_detec = []

    tweet_text = row['content_cleaned']
    for gare_key in stations_rer_a_cleaned_dict.keys():
        for gare in stations_rer_a_cleaned_dict[gare_key]:
            if gare in row['content_cleaned']:
                gare_detec.append((gare, gare_key))
            break

    details = []
    for gare_detected in gare_detec:
        index_deb = tweet_text.find(gare_detected[0])
        index_fin = index_deb + len(gare_detected[0])

        details.append((gare_detected, index_deb, index_fin))

    details = sorted(details, key=lambda x: x[1])

    details_copy = details.copy()

    print(details)
    for index, detail in enumerate(details[1:]):
        index_deb = detail[1]
        index_fin = detail[2]

        old_deb = details[index][1]
        old_fin = details[index][2]   

        if index_deb >= old_deb and index_fin <= old_fin:
            details_copy.remove(detail)
        
    print(details_copy)

    final_gare_detec = [detail[0][1] for detail in details_copy]
    df_f.loc[index, 'gare_detected'] = ",".join(final_gare_detec)"""
# Out:
# 'df_f[\'gare_detected\'] = ""\nfor index, row in df_f.iterrows():\n    gare_detec = []\n\n    tweet_text = row[\'content_cleaned\']\n    for gare_key in stations_rer_a_cleaned_dict.keys():\n        for gare in stations_rer_a_cleaned_dict[gare_key]:\n            if gare in row[\'content_cleaned\']:\n                gare_detec.append((gare, gare_key))\n            break\n\n    details = []\n    for gare_detected in gare_detec:\n        index_deb = tweet_text.find(gare_detected[0])\n        index_fin = index_deb + len(gare_detected[0])\n\n        details.append((gare_detected, index_deb, index_fin))\n\n    details = sorted(details, key=lambda x: x[1])\n\n    details_copy = details.copy()\n\n    print(details)\n    for index, detail in enumerate(details[1:]):\n        index_deb = detail[1]\n        index_fin = detail[2]\n\n        old_deb = details[index][1]\n        old_fin = details[index][2]   \n\n        if index_deb >= old_deb and index_fin <= old_fin:\n            details_copy.remove(detail)\n        \n    print(details_copy)\n\n    final_gare_detec = [detail[0][1] for detail in details_copy]\n    df_f.loc[index, \'gare_detected\'] = ",".join(final_gare_detec)'

# %% [markdown]
# ### Retirer les mots sans importance
# Pour continuer l'étude du contenu, il est temps de maintenant retirer les mots sans importance des tweets, ce qui n'apporte pas de sémantique.
# Si la liste de stopowrds français est assez exhaustive et permet de retirer la majorité des mots inutiles des tweets, cette liste ne contient pas tout. Dans le contexte de la rechercher des incidents du RER A, d'autres mots sont nécessaires à exclure, comme par exemple : rera, actuellement, direction, train... Des mots qui dans le contexte du RER A apparaissent très régulièrement, mais n'apportent pas grand choses puisqu'ici on sait que nos données sont cadrées.

# %%
stopwords_list = stopwords.words('french')+['a', 'rera', 'actuellement', 'direction', 'vers', 'trafic', 'repercussion', "train", "trains", "paris", "h", "cela", "fait", "suite"]


critical_words = ['perturbe', 'raison', 'stationne', 'rer_a', 'entre', 'gare', 'marquent', 'arret', 'autre', 'heure', 'reprise', 'estimee', 'ensemble', 'ligne', 'prolonge', 'reste', 'interrompu', 'stationnent', 'stationnement', 'repart', 'terminus', 'desservie']

stopwords_list = stopwords_list + critical_words

def remove_stations(text):
    for gare_key in stations_rer_a_cleaned_dict:
        for station in stations_rer_a_cleaned_dict[gare_key]:
            text = text.replace(station, '')
    return text

def remove_stopwords(text):
    text = ([word for word in text.split() if word not in stopwords_list])
    return text


df_f['content_removed_gare'] = df_f['content_cleaned'].apply(remove_stations)
df_f['content_removed_sw'] = df_f['content_removed_gare'].apply(remove_stopwords)
df_f['content_cleand_str'] = df_f['content_removed_sw'].apply(lambda x:' '.join(x))

# %% [markdown]
# ## Observation des mots
# Avant d'aller plus loin dans l'analyse, il est pertinent de faire une première observation sur le contenu de tous les tweets confondus. Pour voir la fréquences des mots utilisés, et par la même occasion vérifier qu'il ne reste pas de stopwords à retirer.
# Pourquoi observer les mots ? Eh bien, pour l'instant il n'y a aucun moyen de savoir si un tweet parle d'un incident ou non, le seul moyen de différencier est le champ lexical utilisé pour les tweets en questions.

# %%
def count_bigrams(df, column_name):
    # Initialiser un compteur pour les bigrammes
    bigram_counter = Counter()
    
    # Parcourir chaque ligne de la colonne spécifiée
    for text in df[column_name]:
        # Tokenizer le texte en mots
        tokens = nltk.word_tokenize(text)
        
        # Générer les bigrammes
        bigrams = ngrams(tokens, 2)
        
        # Mettre à jour le compteur de bigrammes
        bigram_counter.update(bigrams)
    
    return bigram_counter
def count_trigrams(df, column_name):
    # Initialiser un compteur pour les bigrammes
    trigram_counter = Counter()
    
    # Parcourir chaque ligne de la colonne spécifiée
    for text in df[column_name]:
        # Tokenizer le texte en mots
        tokens = nltk.word_tokenize(text)
        
        # Générer les bigrammes
        trigrams = ngrams(tokens, 3)
        
        # Mettre à jour le compteur de bigrammes
        trigram_counter.update(trigrams)
    
    return trigram_counter

def count_words(df, column_name):
    # Initialiser un compteur pour les bigrammes
    words_counter = Counter()
    
    # Parcourir chaque ligne de la colonne spécifiée
    for text in df[column_name]:
        # Tokenizer le texte en mots
        tokens = nltk.word_tokenize(text)
        
        # Générer les bigrammes
        words = ngrams(tokens, 1)
        
        # Mettre à jour le compteur de bigrammes
        words_counter.update(words)
    
    return words_counter

bigram_counter = count_bigrams(df_f, 'content_cleand_str')
trigram_counter = count_trigrams(df_f, 'content_cleand_str')
word_counter = count_words(df_f, 'content_cleand_str')

# %%
import matplotlib.cm as cm
import numpy as np

bigrams, counts_bigram = zip(*bigram_counter.most_common(30))
bigrams = [' '.join(bigram) for bigram in bigrams]
df_bigrams = pd.DataFrame({'bigram': bigrams, 'count': counts_bigram})


plt.figure(figsize=(10, 6))
sns.barplot(x='count', y='bigram', data=df_bigrams);

# %%
import matplotlib.cm as cm
import numpy as np

trigrams, counts_trigram = zip(*trigram_counter.most_common(30))
trigrams = [' '.join(trigram) for trigram in trigrams]

df_trigrams = pd.DataFrame({'trigram': trigrams, 'count': counts_trigram})

plt.figure(figsize=(10, 6))
sns.barplot(x='count', y='trigram', data=df_trigrams);

# %%
import matplotlib.cm as cm
import numpy as np

words, counts_words = zip(*word_counter.most_common(30))
words = [' '.join(word) for word in words]

df_words = pd.DataFrame({'word': words, 'count': counts_words})

plt.figure(figsize=(10, 6))
sns.barplot(x='count', y='word', data=df_words);

# %% [markdown]
# Ce graph nous donne des informations importantes quant aux bigram les plus utilisés, et les résultats sont plutot encourageants, puisqu'on voit directement une tendance se dessiner, celle-ci clairement articulée autour des incidents avec des mots comme : bagage oublie, malaise voyageur, signal alarme...

# %% [markdown]
# ## Trier les tweets des incidents de ceux de sujets divers
# L'étude des mots les plus courants peut nous aider dans cette tâche qui va être de séparer les tweets sur les incidents (qu'on souhaite garder) et ceux n'ayant pas les incidents pour thématiques (ceux dont on n'a pas besoin). A cette étape plusieurs solutions sont envisageables : clustering, transformer...Ici je vais utiliser une liste de termes que je vais affiner petit à petit pour être sûr d'includre/exclure les tweets voulus.
#
# On va donc définir 2 listes de termes : une contenant des mots relatif aux incidents, une autres contenant des mots relatifs aux tweets divers. Si un tweet "principal" contient les mots d'une liste ou l'autre, on l'associe à la catégorie associée. Dans le cas où il ne correspond à aucune liste, cela ne change rien puisque cela signifiera qu'il est inutile. On aurait pu définir uniquement une liste de termes, mais pour s'assurer des mauvais tweet, la deuxième liste a été définie.

# %%
df_tweet_normal = df_f[df_f['tweet_type']=='Normal']

words_problem = ['incident', 'oublie', 'perturbe', 'altercation', 'bagarre', 'alarme', 'intervention', 'voie', 'personne', 'malaise', 'inondations', 'panne', 'gene', 'fermeture', 'porte', 'difficulte', 'exploitation', 'rallongement', 'chantier', 'affluence', 'exceptionnelle', 'prefecture', 'police', 'catenaire', 'intervalle', 'retardee', 'degradation', 'regulation', 'fumee', 'securite', 'malveillance']


words_not_problem = ['mardiconseil', 'nouvelarticle', 'nouvel article','jeudiphoto', 'vendredilecture', 'jeu concours', 'hydrater', 'philosopher', 'solliciter', 'respecter', 'animation', 'tchat', 'blog', 'voir plus']

df_f['is_problem'] = False
for i, row in df_f.iterrows():
    if row['tweet_type']=='Normal':
        for word in words_problem:
            if word in row['content_cleand_str']:
                tweet_id = df_f.loc[i, 'thread_id']
                df_f.loc[df_f['thread_id']==tweet_id, 'is_problem'] = True

        for word in words_not_problem:
            if word in row['content_cleand_str']:
                tweet_id = df_f.loc[i, 'thread_id']
                df_f.loc[df_f['thread_id']==tweet_id, 'is_problem'] = False

# %%
df_f[(df_f['tweet_type']=='Normal') & (df_f['is_problem']==False)]['content_cleand_str'].values
# Out:
# array(['mardiconseil lorsque montez bord veillez rester pres portes faciliter montee descente autres voyageurs permet flux plus fluide reduit temps station',
#        'travaux urgents st christophe',
#        'nouvelarticle pourquoi rer affichent codes mysterieux comme zeus qiwi encore taxe decouvrez lettres cachent vraiment derriere chaque trajet',
#        'jeudiphoto images campagne publicitaire rer quoi faire laquelle preferee',
#        'changement',
#        'nouvelarticle attendiez voici decouvrez min renove nouvel article blog',
#        'citation tweet',
#        'mardiconseil parmi questions souvent posees interrogez possibilite avoir portes palieres donne elements reponse ici',
#        'nouvel article automne couleurs aussi saviez feuilles rails peuvent serieusement perturber circulation ferroviaire patinage enrayage decouvrez solutions mises place lire ici',
#        'journeemondialedesanimaux occasion journee mondiale animaux propose petit rappel regles essentielles appliquer lorsque trouve animal bord quai',
#        'jeudiphoto fin annees sauriez deviner quelle trouve min',
#        'mardiconseil prenez trottinette pensez plier avant entrer transportez comme bagage main dutilisation quais ni respectons securite espace chacun',
#        'infotrafic mouvement social interprofessionnel mardi er octobre prevision normal lensemble reseau exploite ratp',
#        'nouvel article faire lorsque oublie affaires rer decouvrons nouvel article blog',
#        'travaux rappel soir jusqu octobre travaux cours aucun circulera weekends gares tous details blog',
#        'travaux travaux prevus octobre novembre retrouvez maintenant details calendrier travaux disponible blog ici',
#        'nouvelarticle ile france mobilites simplifie tarifs decouvrez nouvel article blog',
#        'manga roman webtoon encore journal lisez aujourd hui pendant trajet vendredilecture dites tout',
#        'jeudiphoto revenons retrouver quoi ressemblait bureau information selon quelle',
#        'nouvel article decouvrez comment rer adapte grands evenements festifs concerts supplementaires services renforces equipes mobilisees lire sans attendre tout savoir blog',
#        'mardiconseil etes nombreux solliciter lors incidents justifier retard aupres employeur voyons',
#        'changement',
#        'encore changement changement calendrier partir aujourd hui tous vendredis samedis longs soiree',
#        'nouvelarticle journees europeennes patrimoine arrivent grands rdv blog apprendre plus',
#        'jeudiphoto petit cliche sauriez dire quelle annee',
#        'mardiconseil panne cache sous terme details ci dessous',
#        'animation souhaitez travailler ratp retrouvez agents espace recrutement cote sortie jusqu jeudi tout',
#        'travaux travaux lieu weekends septembre octobre aucun circulera gares tous details blog',
#        'cm bien',
#        'jeudiphoto admirons cette fresque couloir correspondance pensez',
#        'nouvelarticle ratez chance forfait imagine r encore disponible retardataires rdv blog davantage information',
#        'animation decouvrez stadium ratp septembre decouvrez para badminton para athletisme tout',
#        'jeux agents mobilises toute semaine accompagner eleves transitant assister epreuves jeux paralympiques',
#        'mardiconseil bagages debut jusqu fin trajet bagage oublie voire plus',
#        'teamcm souhaite belle rentree hesitez solliciter',
#        'services secours interviennent aupres dune victime dun accident grave tiendrons informes levolution situation',
#        'distributions eau prevues aujourd hui gares',
#        'distributions eau prevues aujourd hui gares',
#        'nouvelarticle jeux ca continue toutes equipes restent presentes accompagner voyageurs sites paralympiques',
#        'travaux retrouvez details travaux prevus septembre octobre calendrier travaux disponible blog ici',
#        'distributions eau prevues aujourd hui gares',
#        'distributions eau prevues aujourd hui gares',
#        'hausse temperatures pensez hydrater avant arrivee emportez eau trajet restez attentifs autres voyageurs hesitez solliciter agents',
#        'mardiconseil rappelons strictement interdit fumer bord quais exposez amende forfaitaire pouvant aller jusqu euros',
#        'jeudiphoto non scene western annees agit bien quai gares actuelles annees sauriez deviner',
#        'mardiconseil souhaitez connaitre horaire passage mieux anticiper trajet voici rubrique consulter',
#        'mardiconseil lors trajets assurer tout passe convenablement agit assistants regulation decouvrez redecouvrez portrait',
#        'distributions eau prevues aujourd hui gares rendez',
#        'distributions eau prevues aujourd hui gares rendez',
#        'reprendra objet delaisse',
#        'distributions eau prevues aujourd hui gares rendez',
#        'distributions eau prevues aujourd hui gares rendez',
#        'jeudiphoto saurez trouver quel pays quelle ville cette entree guimard situee indices entree ville question situee altitude comme deja recu jeux olympiques ete',
#        'mardiconseil escaliers mecaniques pratique restez prudents',
#        'distributions eau prevues aujourd hui gares rendez',
#        'distributions eau prevues aujourd hui gares rendez',
#        'nouvelarticle saviez fortes chaleurs peuvent impacter infrastructures ainsi materiel roulant decouvrez tout nouvel article blog ici',
#        'distributions eau prevues aujourd hui gares',
#        'distributions eau prevues aujourd hui gares',
#        'fortes chaleurs pensez hydrater avant arrivee emportez eau trajet restez attentifs envers autres voyageurs hesitez solliciter agents',
#        'jeudiphoto prenons petit instant contempler vue aerienne sauriez deviner annee prise cette vue',
#        'travaux calendrier travaux mois aout septembre disponible blog ici',
#        'fortes chaleurs distributions bouteilles eau lieu gares agents',
#        'distributions eau prevues aujourd hui gares',
#        'fortes chaleurs pensez hydrater avant arrivee emportez eau trajet restez attentifs envers autres voyageurs hesitez solliciter agents',
#        'animation decouvrez stadium ratp decouvrez tir arc badminton handfit tout',
#        'fortes chaleurs pensez hydrater avant arrivee emportez eau trajet restez attentifs envers autres voyageurs hesitez solliciter agents',
#        'mardiconseil ete forte affluence hautes temperatures omnipresents equipes ventilation refrigeree details fonctionnement expliques ci dessous',
#        'hausse temperatures pensez hydrater avant arrivee emportez eau trajet restez attentifs envers autres voyageurs hesitez solliciter agents',
#        'fortes chaleurs pensez hydrater avant arrivee emportez eau trajet restez attentifs envers autres voyageurs hesitez solliciter agents',
#        'cette journee speciale lateamcm mobilise disposition exceptionnellement jusqu minuit aujourd hui hesitez solliciter',
#        'mardiconseil jeux approchent souhaitez anticiper deplacements retrouvez informations necessaires travers article ci dessous',
#        'nouvelarticle sujets voulez voir blog dites tout sondage present nouvel article blog ici',
#        'jeudiphoto accrochez ms arrive sauriez deviner quelle agit',
#        'lapins ete retrouves hier soir autour heures recherchons proprietaire hesitez contacter si informations rt diffuser',
#        'nouvelarticle empruntez transports commun durant cet ete retrouvez conseils pratiques trajets sereins nouvel article blog ici',
#        'jeudiphoto retour sauriez deviner quelle provient cette vue', '',
#        'animation rendez agents journee gestes sauvent jusqu heures devenez incollable gestes securite adopter transports commun',
#        'mardiconseil souhaitez connaitre horaire passage fiches horaires aussi disposition dates choix tout moment blog ici',
#        'nouvelarticle faire cas malaise quels comportements adopter eviter accident grave comment signaler situation inquietante apprenez bons reflexes avoir nouvel article blog ici',
#        'animation occasion marchedesfiertes retrouvez agents programme distribution bracelets arc ciel maquillage photos serge lapin tout',
#        'travaux retrouvez details travaux soiree prevus juillet aout blog ici',
#        'lisez quoi bord vendredilecture',
#        'jeudiphoto voici ancienne photo sauriez deviner quelle annee date cliche indice vieux',
#        'animation juillet ratp organise journee gestes sauvent agents attendent rer partager bons reflexes avoir transports https ratp fr journee gestes sauvent',
#        'nouvel article avant vacances prenez pouvoir souscrivez forfait imagine r cest rapide retrouvez toutes informations blog',
#        'mardiconseil oubliez hydrater cette journee ensoleillee bouteille eau portee main permettra rester frais pendant trajet',
#        'animation cadre reamenagement salle accueil agents propose echanger autour cafe tout',
#        'fetedelamusique fonctionne toute nuit retrouvez toutes infos ainsi planning animations blog https leblog fr fete musique bout nuit',
#        'nouvelarticle courts surcharges soiree fini decouvrez nouvelle offre soiree nouvel article blog ici',
#        'citation tweet',
#        'bonne chance tous futurs philosophes passe bac aujourd hui cas panne inspiration hesitez philosopher ponctualite',
#        'tchat linfrastructure branche permet mettre plus ny donc possibilite rajouter cest idfm commande grande etude dont resultats connus mi pouvoir voir plus',
#        'tchat va avoir lextension pilotage automatique jusqua cette extension prevue fin lannee',
#        'tchat directeurs installent pouvez venir poser questions direct blog https leblog fr tchat direct directeurs ratp sncf',
#        'tchat rappel pouvez encore poser questions tchat directeurs ratp sncf repondront aujourd hui rdv blog https leblog fr tchat direct directeurs ratp sncf',
#        'retabli',
#        'nouvel article prudents escaliers mecaniques decouvrez conseils securite travers cet article blog',
#        'tchat rappel encore temps poser questions tchat directeurs ratp sncf repondront direct lundi rdv blog https leblog fr tchat direct directeurs ratp sncf',
#        'jeudiphoto pouvez deviner photos fleuries ete prises',
#        'nouvel article gestion dechets organiques priorite rer propre agreable decouvrez comment equipes voyageurs pouvez faire difference',
#        'citation tweet',
#        'mardiconseil voyager securite tenez fermement agrippez deplacez precaution gardez affaires place ecoutez annonces sonores adoptez posture stable bonne route',
#        'tchat rappel pouvez encore poser questions tchat directeurs ratp sncf rdv blog',
#        'presentons excuses agents mobilises retour normale plus vite',
#        'nouvel article chercher passe navigo fond sac fini decouvrez comment faire installer maintenant appareils connectes nouvel article blog https leblog fr telephone devient passe navigo',
#        'jeudiphoto epoque coiffures improbables cols pelle tarte flash back annees sortez walkmans rembobinez cassette lancez meilleur indochine',
#        'mardiconseil parmi incidents lies exploitation peut arriver tombe panne souhaitez savoir comment caracterise article explicatif disponible ici',
#        'tchat questions propos avenir venez poser questions directeurs lors prochain tchat deroulera lundi juin',
#        'fin manifestations station rouverte',
#        'mouvement social mouvement social vendredi mai',
#        'jeudiphoto sauriez deviner quelle annee date jolis cliches',
#        'mouvement social mouvement social vendredi mai'], dtype=object)

# %% [markdown]
# ## Statistiques générales des tweets
# Maintenant que chaque tweet est catégorisé selon s'il contient des informations relatives à des incidents, on peut analyser les données de manière plus générales.

# %% [markdown]
# ### Fréquence de tweet et visibilité

# %%
df_f['date'] = pd.to_datetime(df_f['time_posted'])
start_date = df_f['date'].min()
end_date = df_f['date'].max()

print(f"Période de temps maximale : du {start_date} au {end_date}")
# Out:
# Période de temps maximale : du 2024-05-28 05:55:27 au 2024-12-02 05:40:06

# %%
# Compter le nombre de tweets par jour
df_tweet_normal = df_f[df_f['tweet_type']=='Normal']

tweets_per_day = df_tweet_normal.set_index('date').resample('D').size()
views_per_day = df_tweet_normal.set_index('date')['views'].resample('D').sum()

# %%
tweets_per_day
# Out:
# date
# 2024-05-28    11
# 2024-05-29     7
# 2024-05-30     9
# 2024-05-31     2
# 2024-06-01     9
#               ..
# 2024-10-19     3
# 2024-10-20     3
# 2024-10-21     7
# 2024-10-22    12
# 2024-10-23     9
# Freq: D, Length: 149, dtype: int64

# %%
plt.figure(figsize=(12, 6))

# Créer le premier axe
ax1 = plt.subplot()
ax1.plot(tweets_per_day.index, tweets_per_day.values, label='Nombre de tweets', color='blue')
ax1.set_xlabel('Date')
ax1.set_ylabel('Nombre de tweets', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Créer le second axe
ax2 = ax1.twinx()
ax2.plot(views_per_day.index, views_per_day.values, label='Nombre de vues cumulées', color='red')
ax2.set_ylabel('Nombre de vues', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Ajouter les titres et les légendes
plt.title('Nombre de tweets par jour et nombre de vues cumulées')

# Combiner les légendes des deux axes
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper left')

# Afficher le graphique
plt.show()

# %% [markdown]
# ### Taux engagement

# %%
df_f['engagement'] = ((df_f['likes'] + df_f['retweets'] + df_f['comments']) / df_f['views'])*100



# Tracer l'engagement au fil du temps
df_f['date'] = pd.to_datetime(df_f['time_posted'])
df_tweet_normal = df_f[df_f['tweet_type']=='Normal']
engagement_per_day = df_tweet_normal.set_index('date')['engagement'].resample('D').mean()

plt.figure(figsize=(12, 6))
engagement_per_day.plot()
plt.title('Engagement par jour')
plt.xlabel('Date')
plt.ylabel('Engagement')
plt.show()

# %% [markdown]
# ## Trouver différents types incidents (non supervisé)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(tweet_normaux_incidents['content_cleand_str'])


inertia = []
for k in range(2,60):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

plt.plot(inertia)
x = range(1, len(inertia)+1)
kn = KneeLocator(x, inertia, curve='convex', direction='decreasing')
print(kn.knee)
# Out:
# c:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 13
#      11 for k in range(2,60):
#      12     kmeans = KMeans(n_clusters=k)
# ---> 13     kmeans.fit(X)
#      14     inertia.append(kmeans.inertia_)
#      16 plt.plot(inertia)
#
# File c:\Python311\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1515, in KMeans.fit(self, X, y, sample_weight)
#    1511 best_inertia, best_labels = None, None
#    1513 for i in range(self._n_init):
#    1514     # Initialize centers
# -> 1515     centers_init = self._init_centroids(
#    1516         X,
#    1517         x_squared_norms=x_squared_norms,
#    1518         init=init,
#    1519         random_state=random_state,
#    1520         sample_weight=sample_weight,
#    1521     )
#    1522     if self.verbose:
#    1523         print("Initialization complete")
#
# File c:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1018, in _BaseKMeans._init_centroids(self, X, x_squared_norms, init, random_state, init_size, n_centroids, sample_weight)
#    1015     sample_weight = sample_weight[init_indices]
#    1017 if isinstance(init, str) and init == "k-means++":
# -> 1018     centers, _ = _kmeans_plusplus(
#    1019         X,
#    1020         n_clusters,
#    1021         random_state=random_state,
#    1022         x_squared_norms=x_squared_norms,
#    1023         sample_weight=sample_weight,
#    1024     )
#    1025 elif isinstance(init, str) and init == "random":
#    1026     seeds = random_state.choice(
#    1027         n_samples,
#    1028         size=n_clusters,
#    1029         replace=False,
#    1030         p=sample_weight / sample_weight.sum(),
#    1031     )
#
# File c:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:271, in _kmeans_plusplus(X, n_clusters, x_squared_norms, sample_weight, random_state, n_local_trials)
#     269 # Permanently add best center candidate found in local tries
#     270 if sp.issparse(X):
# --> 271     centers[c] = X[best_candidate].toarray()
#     272 else:
#     273     centers[c] = X[best_candidate]
#
# File c:\Python311\Lib\site-packages\scipy\sparse\_compressed.py:1061, in _cs_matrix.toarray(self, order, out)
#    1059     y = out.T
#    1060 M, N = x._swap(x.shape)
# -> 1061 csr_todense(M, N, x.indptr, x.indices, x.data, y)
#    1062 return out
#
# KeyboardInterrupt:

# %%
from sentence_transformers import SentenceTransformer

#model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-mpnet-base-v2') ## 9 clusters, avec 1 ou 2 peu cohérents
model = SentenceTransformer('intfloat/multilingual-e5-base') ## 9 clusters, un peu mieux, toujours 1 ou 2 peu cohérents
#model = SentenceTransformer('dangvantuan/sentence-camembert-large') ## 8 clusters, plutot bon, 1 cluster bullshit
#model = SentenceTransformer('sentence-transformers/LaBSE') ## 11 clusters, plutot bons, 2~3 clusters bullshit
#model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2') ## 8 clusters, plutot bons, 1 cluster bullshit


## Solution = cleaner encore plus les texte car certains ne sont pas des tweets d'incidents

# %%
tweet_incidents = df_f[df_f['is_problem']==True]
tweet_normaux_incidents = tweet_incidents[tweet_incidents['tweet_type']=='Normal']


#df_vectors = model.encode(tweet_normaux_incidents['content_cleand_str'].values)
df_vectors = model.encode(tweet_normaux_incidents['content_removed_gare'].values)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.99)  # Vous pouvez ajuster le nombre de composantes principales
principal_components = pca.fit_transform(df_vectors)

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import AffinityPropagation
from sklearn.cluster import DBSCAN

clustering = DBSCAN(eps=0.4, min_samples=1).fit(principal_components)
clustering.labels_

# %%
from sklearn.cluster import KMeans


inertia = []
for k in range(2,60):
    kmeans = KMeans(n_clusters=k, n_init='auto', max_iter=5000, tol=1e-6)
    kmeans.fit(principal_components)
    inertia.append(kmeans.inertia_)

plt.plot(inertia)

# %%
from kneed import KneeLocator

x = range(1, len(inertia)+1)
kn = KneeLocator(x, inertia, curve='convex', direction='decreasing')
print(kn.knee)
# Out:
# 5

# %%
kmeans = KMeans(n_clusters=14, n_init='auto')
kmeans.fit(principal_components)

tweet_normaux_incidents['cluster'] = kmeans.labels_
# Out:
# C:\Users\gabriel\AppData\Local\Temp\ipykernel_25088\135117694.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweet_normaux_incidents['cluster'] = kmeans.labels_

# %%
tweet_normaux_incidents.groupby(['nb_gare_detected', 'cluster']).size()
# Out:
# nb_gare_detected  cluster
# 1                 1            7
#                   2            4
#                   3           11
#                   4            1
#                   5            2
#                   6            6
#                   7            2
#                   8            1
#                   9            5
#                   10           3
#                   12           1
# 2                 1           97
#                   2            2
#                   3            4
#                   4          122
#                   5           25
#                   6            7
#                   7          104
#                   8            3
#                   9           32
#                   10          10
#                   11          29
#                   12           5
#                   13          21
# 3                 0            1
#                   1            3
#                   2           21
#                   3           54
#                   4            4
#                   5            3
#                   6           23
#                   7           12
#                   8           27
#                   10          57
#                   11           4
#                   12          27
#                   13           5
# 4                 2            1
#                   3           15
#                   4            1
#                   5            3
#                   6            8
#                   7            4
#                   8            8
#                   10          10
#                   11           4
#                   13           2
# 5                 1            1
#                   2            1
#                   3            2
#                   6            5
#                   7            2
#                   8            4
#                   10           4
#                   12           2
#                   13           3
# 6                 3            1
#                   6            1
#                   8            1
# dtype: int64

# %%
content = tweet_normaux_incidents[tweet_normaux_incidents['cluster']==13]['content_cleand_str'].values
print(content)
# Out:
# ['bagage oublie' 'bagage oublie' 'bagage oublie quai' 'bagage oublie quai'
#  'bagage oublie' 'bagage oublie' 'bagage oublie' 'bagage oublie'
#  'bagage oublie bord' 'deux sens circulation bagage oublie'
#  'bagage oublie' 'saint christophe bagage oublie' 'bagage oublie'
#  'bagage oublie' 'bagage oublie quai' 'bagage oublie' 'bagage oublie quai'
#  'bagage oublie' 'bagage oublie' 'bagage oublie' 'bagage oublie'
#  'bagage oublie' 'quai bagage oublie' 'bagage oublie' 'bagage oublie'
#  'bagage oublie' 'bagage oublie' 'bagage oublie' 'bagage oublie'
#  'bagage oublie' 'bagage oublie']

# %% [markdown]
# ## Trouver cluster lda

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from gensim import corpora
from gensim.models.ldamulticore import LdaMulticore
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt
import gensim


tweet_incidents = df_f[df_f['is_problem']==True]
tweet_normaux_incidents = tweet_incidents[tweet_incidents['tweet_type']=='Normal']

id2word = corpora.Dictionary(tweet_normaux_incidents['content_cleand_str'].apply(lambda x: x.split()))  
# Create Corpus 
texts = tweet_normaux_incidents['content_cleand_str'].apply(lambda x: x.split())  
# Term Document Frequency 
corpus = [id2word.doc2bow(text) for text in texts]  
# View 

coherence = []
for num_topics in range(2,40):
    print(num_topics)
    lda_model = LdaMulticore(corpus=corpus, id2word=id2word, num_topics=num_topics, random_state=42, passes=10, workers=2)

    coherence_model_lda = CoherenceModel(model=lda_model, texts=texts, dictionary=id2word, coherence='c_v')
    coherence_lda = coherence_model_lda.get_coherence()
    coherence.append(coherence_lda)
# Out:
# 2
# 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[193], line 23
#      21 for num_topics in range(2,40):
#      22     print(num_topics)
# ---> 23     lda_model = LdaMulticore(corpus=corpus, id2word=id2word, num_topics=num_topics, random_state=42, passes=10, workers=2)
#      25     coherence_model_lda = CoherenceModel(model=lda_model, texts=texts, dictionary=id2word, coherence='c_v')
#      26     coherence_lda = coherence_model_lda.get_coherence()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\models\ldamulticore.py:186, in LdaMulticore.__init__(self, corpus, num_topics, id2word, workers, chunksize, passes, batch, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, random_state, minimum_probability, minimum_phi_value, per_word_topics, dtype)
#     183 if isinstance(alpha, str) and alpha == 'auto':
#     184     raise NotImplementedError("auto-tuning alpha not implemented in LdaMulticore; use plain LdaModel.")
# --> 186 super(LdaMulticore, self).__init__(
#     187     corpus=corpus, num_topics=num_topics,
#     188     id2word=id2word, chunksize=chunksize, passes=passes, alpha=alpha, eta=eta,
#     189     decay=decay, offset=offset, eval_every=eval_every, iterations=iterations,
#     190     gamma_threshold=gamma_threshold, random_state=random_state, minimum_probability=minimum_probability,
#     191     minimum_phi_value=minimum_phi_value, per_word_topics=per_word_topics, dtype=dtype,
#     192 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\models\ldamodel.py:521, in LdaModel.__init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics, callbacks, dtype)
#     519 use_numpy = self.dispatcher is not None
#     520 start = time.time()
# --> 521 self.update(corpus, chunks_as_numpy=use_numpy)
#     522 self.add_lifecycle_event(
#     523     "created",
#     524     msg=f"trained {self} in {time.time() - start:.2f}s",
#     525 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\models\ldamulticore.py:316, in LdaMulticore.update(self, corpus, chunks_as_numpy)
#     312 # endfor single corpus pass
#     313
#     314 # wait for all outstanding jobs to finish
#     315 while queue_size[0] > 0:
# --> 316     process_result_queue(force=True)
#     318 if reallen != lencorpus:
#     319     raise RuntimeError("input corpus size changed during training (don't use generators as input)")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\models\ldamulticore.py:283, in LdaMulticore.update.<locals>.process_result_queue(force)
#     281 other.reset()
#     282 if eval_every > 0 and (force or (self.num_updates / updateafter) % eval_every == 0):
# --> 283     self.log_perplexity(chunk, total_docs=lencorpus)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\models\ldamodel.py:847, in LdaModel.log_perplexity(self, chunk, total_docs)
#     845 corpus_words = sum(cnt for document in chunk for _, cnt in document)
#     846 subsample_ratio = 1.0 * total_docs / len(chunk)
# --> 847 perwordbound = self.bound(chunk, subsample_ratio=subsample_ratio) / (subsample_ratio * corpus_words)
#     848 logger.info(
#     849     "%.3f per-word bound, %.1f perplexity estimate based on a held-out corpus of %i documents with %i words",
#     850     perwordbound, np.exp2(-perwordbound), len(chunk), corpus_words
#     851 )
#     852 return perwordbound
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\models\ldamodel.py:1113, in LdaModel.bound(self, corpus, gamma, subsample_ratio)
#    1111     logger.debug("bound: at document #%i", d)
#    1112 if gamma is None:
# -> 1113     gammad, _ = self.inference([doc])
#    1114 else:
#    1115     gammad = gamma[d]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\models\ldamodel.py:722, in LdaModel.inference(self, chunk, collect_sstats)
#     720 Elogthetad = dirichlet_expectation(gammad)
#     721 expElogthetad = np.exp(Elogthetad)
# --> 722 phinorm = np.dot(expElogthetad, expElogbetad) + epsilon
#     723 # If gamma hasn't changed much, we're done.
#     724 meanchange = mean_absolute_difference(gammad, lastgamma)
#
# KeyboardInterrupt:

# %%
plt.plot(coherence)

# %%
tweet_incidents = df_f[df_f['is_problem']==True]
tweet_normaux_incidents = tweet_incidents[tweet_incidents['tweet_type']=='Normal']

id2word = corpora.Dictionary(tweet_normaux_incidents['content_cleand_str'].apply(lambda x: x.split()))  
# Create Corpus 
texts = tweet_normaux_incidents['content_cleand_str'].apply(lambda x: x.split())  
# Term Document Frequency 
corpus = [id2word.doc2bow(text) for text in texts]  

lda_model = LdaMulticore(corpus=corpus, id2word=id2word, num_topics=16, random_state=42, passes=10, workers=2)

# %%
tweet_topics = []
for i, tweet_bow in enumerate(corpus):
    topics = lda_model.get_document_topics(tweet_bow)
    # Trouver le topic avec la probabilité la plus élevée
    main_topic = max(topics, key=lambda x: x[1])
    tweet_topics.append(main_topic[0])

# Ajouter les topics au DataFrame
tweet_normaux_incidents['main_topic'] = tweet_topics
# Out:
# C:\Users\gabriel\AppData\Local\Temp\ipykernel_20472\3912071561.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweet_normaux_incidents['main_topic'] = tweet_topics

# %%
tweet_normaux_incidents.groupby('main_topic').size()
# Out:
# main_topic
# 1       6
# 2      61
# 3      34
# 4       3
# 5      78
# 6       3
# 7       6
# 8       5
# 9     117
# 10      7
# 11     21
# 12     89
# 13      1
# 14      8
# 15     32
# dtype: int64

# %%
tweet_normaux_incidents.groupby('main_topic').size()
for idx, topic in lda_model.print_topics(-1):
    terms = [term.split('*')[1].replace('"', '').strip() for term in topic.split(' + ')]
    print(f"Topic {idx}:")
    print(", ".join(terms))
    print("\n")
# Out:
# Topic 0:
# terminus, affcetant, desservi, actionnement, signal, alarme, incident, voie, retabli, bagage
#
#
# Topic 1:
# stationnent, voies, personnes, incident, reprendra, regulier, fin, intervalle, ajustement, retour
#
#
# Topic 2:
# bagage, oublie, stationnent, tres, reprend, progressivement, bord, stationnement, difficultes, voie
#
#
# Topic 3:
# incident, technique, voyageur, journee, trajet, pendant, portee, rester, permettra, main
#
#
# Topic 4:
# incident, avril, passe, expliquons, retour, blog, matin, tout, ici, intervention
#
#
# Topic 5:
# incident, exploitation, voyageur, difficultes, voyageurs, incidents, panne, maximum, informer, puissent
#
#
# Topic 6:
# quai, stationnent, bagage, oublie, personne, presence, voies, circulation, deux, sens
#
#
# Topic 7:
# panne, retabli, incident, electrique, lie, termine, stationnent, dun, desservie, rerao
#
#
# Topic 8:
# stationnement, voyageurs, altercation, deux, malaises, signal, alarme, actionnement, abusif, difficultes
#
#
# Topic 9:
# alarme, signal, actionnement, incident, intervention, necessitant, agents, affectant, voie, terminus
#
#
# Topic 10:
# interrompue, trajet, travauxrera, rer, poursuivre, zone, dernier, dela, permettant, min
#
#
# Topic 11:
# incident, intervention, necessitant, conducteur, stationnement, signalisation, incidents, creation, tchat, informer
#
#
# Topic 12:
# agents, necessitant, incident, intervention, lintervention, nouveau, perturbation, signal, alarme, actionnement
#
#
# Topic 13:
# alarme, signal, mardiconseil, cet, fonctionne, fonctionnement, retrouvez, travers, comment, article
#
#
# Topic 14:
# affectant, voies, incident, stationnement, equipes, techniques, intervention, fin, repart, voyageur
#
#
# Topic 15:
# incident, voie, affectant, malaise, voyageur, stationnement, ref, exploitation, oublie, bagage

# %%
tweet_normaux_incidents[tweet_normaux_incidents['main_topic']==5]['content_cleand_str'].values
# Out:
# array(['incident exploitation', 'incident exploitation', 'inondations',
#        'incident voyageur', 'incident exploitation', 'incident voyageur',
#        'incident voyageur', 'incident voyageur', 'incident exploitation',
#        'incident voyageur', 'incident voyageur', 'incident voyageur',
#        'incident exploitation', 'incident exploitation',
#        'incident exploitation', 'incident exploitation',
#        'incident voyageur', 'incident exploitation',
#        'incident exploitation', 'incident voyageur',
#        'incident exploitation', 'incident exploitation',
#        'incident exploitation', 'incident exploitation',
#        'incident exploitation', 'incident exploitation',
#        'incident exploitation', 'incident exploitation',
#        'incident exploitation', 'incident voyageur',
#        'incident voyageur panne',
#        'stationnement difficultes exploitation',
#        'incident voyageur garconnet jambe bloquee quai',
#        'incident voyageur',
#        'mardiconseil parmi incidents lies exploitation peut arriver tombe panne souhaitez savoir comment caracterise article explicatif disponible ici',
#        'stationnement difficultes exploitation',
#        'incident voyageur jupe coincee portes',
#        'incident exploitation quai', 'tres incident exploitation',
#        'incident voyageur bagarre voyageurs', 'incident exploitation',
#        'incident exploitation', 'incident voyageur', 'incident voyageur',
#        'incident exploitation', 'stationnement incident voyageur',
#        'incident exploitation', 'incident exploitation',
#        'incident voyageur', 'incident exploitation',
#        'incident exploitation',
#        'quai stationnent difficultes exploitation',
#        'incident exploitation', 'stationnement incident voyageur',
#        'incident exploitation',
#        'tchat role ccu aussi donner maximum dinformations conducteurs quils puissent tour informer voyageurs incidents cours',
#        'incident voyageur', 'incident exploitation', 'incident voyageur',
#        'incident exploitation', 'incident exploitation',
#        'incident voyageur', 'incident exploitation',
#        'incident exploitation', 'incident exploitation',
#        'stationnement incident exploitation', 'incident exploitation',
#        'reprendra bagage oublie invitons emprunter itineraires alternatifs rapprocher agents',
#        'incident exploitation', 'incident exploitation',
#        'ref incident exploitation', 'ref incident exploitation',
#        'incident exploitation panne signalisation',
#        'incident exploitation', 'incident exploitation',
#        'incident exploitation', 'incident exploitation',
#        'incident voyageur'], dtype=object)

# %% [markdown]
# ## Trouver les différents types d'incidents (manuel classification)

# %%
import pandas as pd
import sys

df_f = pd.read_csv("df_f.csv")


for i,row in df_f.iterrows():
    
    if row['tweet_type']!='Normal':
        continue

    print(row['content'])
    sys.stdout.flush()  # Forcer le vidage du tampon de sortie

    is_problem = row['is_problem']
    label = row['label']
    print("----")
    is_problem_user = input(f"Est-ce un problème pour la ligne {i} (oui/non) ? ({is_problem}) : ")
    label_user = input(f"Entrez le label pour la ligne {i} {label} ")

    df_f.at[i, 'is_problem'] = is_problem_user.lower() == 'oui'
    df_f.at[i, 'label'] = label_user


    df_f.to_csv("df_f.csv", index=False)

exploitation
alarme
agent
bagage
sur_voie
malaise
conducteur
technique
inondation
arbre
altercation
aff_voie
ferm_porte
train_panne
accident_pers
panne_elec
signalisation
panne_train
voyageur
panne_porte
police
sortie_garage
catenaire
ajustement_interv
rallong_chantier
degradation
# Out:
#  Le trafic est perturbé de Poissy vers Nanterre - Préfecture , en raison d'un incident d'exploitation à Poissy #RERA
# ----
#  Le train stationne à Gare de Lyon en direction de Cergy–Le Haut en raison de l'actionnement d'un signal d'alarme. #RERA
# ----
#
le train actuellement à La Varenne–Chennevières et en direction de Boissy-Saint-Léger stationne en raison d'un incident technique à Sucy – Bonneuil. #RERA
# ----
# Le train actuellement à Sucy – Bonneuil et en direction de Boissy-Saint-Léger stationne en raison d'un incident technique. #RERA
# ----
#  Les trains ne marquent pas l'arrêt en gare de La Varenne–Chennevières (inondations). #RERA
# ----
# Le train actuellement entre Sucy – Bonneuil et La Varenne–Chennevières et en direction de Poissy stationne en raison de la chute d'un arbre sur les voies. #RERA
# ----
# Le train actuellement à Neuville-Université et en direction de Boissy-Saint-Léger stationne en raison d'une altercation entre voyageurs. #RERA
# ----
# Le train actuellement à Maisons-Laffitte et en direction de Cergy–Le Haut stationne en raison d'un incident affectant la voie. #RERA
# ----
# Les train actuellement entre Fontenay-sous-Bois et Joinville-le-Pont stationnent en raison de la présence d'une personne sur les voies. #RERA
# ----
# [#Travaux] Le calendrier des travaux des mois d'août et septembre est disponible sur le blog du #RERA ici
# ----
# Le train actuellement à Boissy-Saint-Léger et en direction de Cergy–Le Haut stationne en raison d'un incident technique. #RERA
# ----
# [Fortes chaleurs ] : Des distributions de bouteilles d'eau ont lieu dans les gares #RERA Nos agents sont là pour vous
# ----
# Les trains stationnent entre La Défense et Vincennes, en raison d'un incident nécessitant l'intervention de nos agents à Gare de Lyon. #RERA
# ----
# Le train actuellement à Rueil-Malmaison et en direction de Saint-Germain-en-Laye stationne en raison de l'intervention des agents. #RERA
# ----
# Le train actuellement à La Varenne–Chennevières et en direction de Cergy-Le Haut stationne en raison de l'intervention des agents. #RERA
# ----
# Des distributions d'eau  sont prévues aujourd'hui dans vos gares #RERA de :
# La Défense à 13h30 et 17h
# Châtelet-Les Halles vers 18h
# Gare de Lyon à 16h
# Nation à 15h
# Vincennes à 17h
# Bussy-Saint-Georges à 13h et à 19h
# Marne-la-Vallée-Chessy à 15h
# ----
# Le train actuellement à Noisiel et en direction de Saint-Germain-en-Laye stationne en raison d'une gêne à la fermeture des portes. #RERA
# ----
# Le train actuellement à Maisons-Laffitte et en direction de Boissy-Saint-Léger stationne en raison d'un incident nécessitant l'intervention des agents. #RERA
# ----
# [Fortes chaleurs ] : Pensez à vous hydrater avant votre arrivée en gare et emportez de l'eau pour votre trajet. Restez attentifs envers les autres voyageurs et n'hésitez pas à solliciter les agents #RERA
# ----
#  Le trafic est interrompu entre Nation et Val de Fontenay, et entre Fontenay-sous-Bois et Nation (train en panne). Reprise estimée : 06:00. #RERA
# ----
#  Le trafic est interrompu entre Houilles Carrières-sur-Seine et Nanterre -Préfecture et perturbé sur le reste de la ligne (accident grave de personne). Reprise estimée : 07:30. #RERA
# ----
# Le train actuellement à Houilles et en direction de Boissy-Saint-Léger stationne en raison d'une panne électrique. #RERA
# ----
#  Le trafic est perturbé de La Défense vers Marne-la-Vallée–Chessy • Boissy-Saint-Léger en raison d'un incident affectant les voies à Vincennes. #RERA
# ----
# Le train actuellement à Vincennes et en direction de Boissy-Saint-Léger stationne en raison d'un incident affectant les voies. #RERA
# ----
# Le train actuellement à Vincennes et en direction de Marne-la-Vallée–Chessy stationne en raison d'un incident affectant la voie. #RERA
# ----
# Le train actuellement à Nanterre – Préfecture et en direction de Cergy-le Haut stationne en raison de l'actionnement d'un signal d'alarme. #RERA
# ----
# Le train actuellement à son terminus à Marne-la-Vallée–Chessy stationne en raison d'un malaise voyageur. #RERA
# ----
# Le train actuellement à La Varenne–Chennevières et en direction de Boissy-Saint-Léger stationne en raison de l'intervention des agents. #RERA
# ----
# Le train actuellement à Rueil-Malmaison et en direction de Saint-Germain-en-Laye stationne en raison d'un incident nécessitant l'intervention du conducteur. #RERA
# ----
# [Animation] Découvrez le stadium RATP en gare d'Auber de 12:00 à 18:00 et découvrez le tir à l'arc, le badminton et le handfit ! À tout à l'heure !
# ----
# Fin de stationnement. Le train repart en direction de Marne-la-Vallée–Chessy (intervention des équipes techniques.). #RERA
# ----
# Le train actuellement entre Vincennes et Val de Fontenay et en direction de Marne-la-Vallée–Chessy stationne en raison de l'interv
en direction de Poissy stationne en raison d'un incident nécessitant l'intervention du conducteur. #RERA
# ----
# [#MardiConseil] Les Jeux de Paris 2024 approchent et vous souhaitez anticiper vos déplacements ? Retrouvez les informations nécessaires à travers l'article ci-dessous. #RERA
# ----
# Le train actuellement à Sartrouville et en direction de Cergy–Le Haut stationne en raison d'une panne. #RERA
# ----
#  Le trafic est perturbé de Cergy-Le Haut vers Nanterre Préfecture en raison d'un incident d'exploitation à Cergy – Le Haut. #RERA
# ----
# Le trafic est perturbé de Vincennes vers Cergy-Le-Haut/Poissy et St-Germain-En-Laye, en raison d'un malaise voyageur à Charles de Gaulle – Étoile  #RERA
# ----
# Le train actuellement à Marne-la-Vallée–Chessy et en direction de Saint-Germain-en-Laye stationne en raison d'une sortie de garage retardée. #RERA
# ----
# Le train actuellement à Noisy-le-Grand-Mont d'Est et en direction de Saint-Germain-en-Laye stationne en raison de l'actionnement d'un signal d'alarme. #RERA
# ----
# Le train actuellement à Achères-Ville et en direction de Boissy-Saint-Léger stationne en raison de l'actionnement d'un signal d'alarme. #RERA
# ----
# Le train actuellement à Gare de Lyon et en direction de Boissy-Saint-Léger stationne en raison d'un bagage oublié... #RERA
# ----
#  Le stationnement est prolongé à Torcy en direction de Poissy, en raison d'un incident nécessitant l'intervention du conducteur. #RERA
# ----
#  Le stationnement est prolongé à La Défense en direction de Marne-la-Vallée – Chessy, en raison d'un incident nécessitant l'intervention de nos agents. #RERA
# ----
# Le trafic est perturbé de Vincennes vers St Germain / Cergy le Haut/ Poissy sur le #RERA, en raison d'un incident voyageur à Châtelet – Les Halles.
# ----
# Le trafic est perturbé de Cergy le Haut vers Marne la Vallée sur le #RERA, en répercussion d'un malaise voyageur à Cergy – Saint-Christophe.
# ----
# Un train stationne à Poissy en direction de Marne-la-Vallée – Chessy sur le #RERA, en raison d'un train en panne  .
# ----
# Un train stationne à Nanterre – Préfecture en direction de Boissy-Saint-Léger sur le #RERA, en raison d'un incident nécessitant l’intervention de nos agents .
# ----
# Le trafic est interrompu entre Achères Ville et Maisons-Laffite en raison d'une chute de caténaire. La reprise est estimée vers 07h00. Le trafic est très perturbé sur le reste de la ligne. #RERA
# ----
# Le train actuellement à Vincennes et en direction de La Défense stationne en raison d'un incident affectant la voie. #RERA
# ----
#  Le trafic est interrompu entre Nanterre – Préfecture et Cergy-Le Haut • Poissy et très perturbé sur le reste de la ligne en raison d'une rupture de caténaire à Achères-Ville. Reprise estimée à 20:00. #RERA
# ----
# Le train actuellement à Bussy-Saint-Georges et en direction de Marne-la-Vallée–Chessy stationne en raison d'un accident grave de personnes. #RERA
# ----
# Le train actuellement à Val de Fontenay et en direction de  Marne-la-Vallée–Chessy stationne en raison d'un incident voyageur. #RERA
# ----
# Le train actuellement à Lognes et en direction de Marne-la-Vallée–Chessy stationne en raison d'une gêne à la fermeture des portes d'un train.  #RERA
# ----
# Le train actuellement à Nanterre – Préfecture et en direction de Saint-Germain-en-Laye stationne en raison d'un incident nécessitant l'intervention des agents. #RERA
# ----
# Le train actuellement à Cergy–Saint-Christophe et en direction de Boissy-Saint-Léger stationne en raison d'un bagage oublié dans un train. #RERA
# ----
# Le train actuellement à La Défense et en direction de Saint-Germain-en-Laye stationne en raison de l'intervention des forces de l'ordre. #RERA
# ----
# Le train actuellement à Noisy-le-Grand-Mont d'Est et en direction de Marne-la-Vallée–Chessy stationne en raison d'un incident nécessitant l'intervention des agents. #RERA
# ----
#  Le trafic est perturbé de Conflans-Fin d'Oise vers Cergy-le-Haut en raison d'un train en panne à Conflans – Fin d’Oise . #RERA
# ----
#  Le trafic est perturbé de Rueil-Malmaison vers Marne-La-Vallée Chessy en raison d'une panne de portes de train à Rueil-Malmaison. #RERA
# ----
#  Le trafic est perturbé de Saint Germain en-Laye vers Vincennes en raison d'un train en panne à Saint-Germain-en-Laye . #RERA
# ----
#  Le trafic est rétabli sur la ligne (intervention des forces de l'ordre à Nation). #RERA
# ----
# Le train actuellement à Nation et en direction de Saint-Germain-en-Laye stationne en raison de l'intervention
le train actuellement à Val d'Europe et en direction de Marne-la-Vallée–Chessy stationne en raison d'un bagage oublié sur le quai à Marne-la-Vallée–Chessy. #RERA
# ----
#  Le trafic est perturbé de Poissy vers Nanterre-Préfecture (gêne à la fermeture des portes d'un train). #RERA
# ----
#  Le trafic est perturbé de Poissy vers Nanterre-Préfecture en raison d'un train en panne à Poissy. #RERA
# ----
# Le train actuellement à Neuilly-Plaisance et en direction de Saint-Germain-en-Laye stationne en raison de l'intervention des agents. #RERA
# ----
# Le train actuellement à Nanterre Université et en direction de Marne-la-Vallée–Chessy stationne en raison d'un incident technique. #RERA
# ----
# Le train actuellement à Torcy et en direction de Marne-la-Vallée–Chessy stationne en raison d'un incident nécessitant l'intervention des agents. #RERA
# ----
#  Le trafic est perturbé de Nanterre–Préfecture vers Cergy–Le Haut en raison d'un train en panne à Nanterre–Préfecture. #RERA
# ----
#  Le trafic est perturbé de Poissy vers Nanterre–Préfecture en raison d'un train en panne à Poissy. #RERA
# ----
#  Le trafic est interrompu entre Torcy et Bussy-Saint-Georges et reprendra vers 13:00. Cela fait suite à une intervention des équipes techniques à Bussy-Saint-Georges. Nous vous invitons à emprunter des itinéraires alternatifs. #RERA
# ----
#  Un train stationne à Bussy-Saint-Georges en direction de Cergy – Le Haut, en raison d'une intervention des équipes techniques sur la voie. #RERA
# ----
#   le trafic est perturbé de MLV-Chessy vers Poissy, en raison d'une dégradation volontaire à Torcy. #RERA
# ----
#  Le train stationne à Charles de Gaulle–Étoile en direction de Marne-la-Vallée–Chessy en raison de l'actionnement d'un signal d'alarme. #RERA
# ----
# Un train stationne à Auber en direction de Saint-Germain-en-Laye, en raison de l'actionnement d'un signal d'alarme. #RERA
# ----
#  Un train stationne entre Neuilly-Plaisance et Bry-sur-Marne en direction de Marne-la-Vallée – Chessy, en raison de personnes sur les voies à Neuilly-Plaisance. #RERA
# ----
# Le train actuellement à Gare de Lyon et en direction de Boissy-Saint-Léger stationne en raison de l'intervention du conducteur. #RERA
# ----
#  Ces #lapins ont été retrouvés hier soir en gare #RERA de Châtelet–Les Halles autour de 19 heures. Nous recherchons leur propriétaire ! N'hésitez pas à nous contacter si vous avez des informations, et RT pour diffuser !
# ----
# Le train actuellement à Fontenay-sous-Bois et en direction de Boissy-Saint-Léger stationne en raison d'une gêne à la fermeture des portes. #RERA
# ----
#  Le trafic est perturbé entre Vincennes et Boissy-St-Léger, en raison d'un bagage oublié dans un train à Boissy-Saint-Léger. #RERA
# ----
# Le trafic est perturbé de Marne La Vallée - Chessy vers Saint Germain en Laye, en raison d'un incident d'exploitation à Marne-la-Vallée – Chessy. #RERA
# ----
#  Le trafic est rétabli sur la ligne (actionnement d'un signal d'alarme). #RERA
# ----
# Le train actuellement à Val de Fontenay et en direction de Marne-la-Vallée–Chessy stationne en raison de l'actionnement d'un signal d'alarme. #RERA
# ----
# [#NouvelArticle ] Vous empruntez les transports en commun durant cet été ? Retrouvez nos conseils pratiques pour des trajets sereins dans notre nouvel article du blog #RERA ici
# ----
# Le train actuellement à Gare de Lyon et en direction de Marne-la-Vallée–Chessy stationne en raison de l'actionnement d'un signal d'alarme. #RERA
# ----
# [#JeudiPhoto ] Retour en 1964 ! Sauriez-vous deviner de quelle gare provient cette vue ? #RERA
# ----
# Le train actuellement à Charles de Gaulle–Étoile et en direction de Boissy-Saint-Léger stationne en raison de l'actionnement d'un signal d'alarme. #RERA
# ----
# Le train actuellement à Nation et en direction de Cergy–Le Haut stationne en raison de l'actionnement d'un signal d'alarme. #RERA
# ----
#  Un train stationne à Chatelet les Halles en direction de Cergy/Poissy #RERA
# ----
#  Le trafic est perturbé de Nanterre-Préfecture vers Cergy-Le Haut en raison d'un train en panne à Cergy – Saint-Christophe. #RERA
# ----
#  Le trafic est perturbé de Boissy-Saint-Léger vers St-Germain-En-Laye, en raison d'un rallongement de durée de chantier à Boissy-Saint-Léger. #RATP
# ----
# Le stationnement est prolongé à Fontenay-sous-Bois en direction de Saint-Germain-en-Laye, en raison d'un malaise voyageur. #RERA
# ----
# Le train actuellement à Noisiel et en direction de Marne-la-Vallée–Chessy stationne en raison de la présence d'une personne sur les voies. #RERA
# ----
# Le train actuellement à Charles de Gaulle–Étoile et en direction de Boissy-Saint-Léger stationne en raison de l'intervention des agents. #RERA
# ----
# Le train actuellement à La Défense et en direction de Cergy–Le Haut stationne en raison d'un incident technique. #RERA
# ----
# Le train actuellement à Val d'Europe et en direction de Marne-la-Vallée–Chessy stationne en raison de l'actionnement d'un signal d'alarme. #RERA
# ----
# [#Animation] Rendez-vous en gare #RERA d'Auber avec nos agents pour la "journée des gestes qui sauvent" jusqu'à 20 heures. Devenez incollable sur les gestes de sécurité à adopter dans les transports en commun !
# ----
#  Le trafic est perturbé de Cergy-Le-Haut • Poissy vers Nanterre Préfecture, en raison d'un incident d'exploitation à Maisons-Laffitte. #RERA
# ----
#  Le trafic est perturbé entre Val de Fontenay et Marne-la-Vallée-Chessy, en raison d'un bagage oublié dans un train à Marne-la-Vallée – Chessy. #RERA
# ----
#  Le trafic est perturbé entre Boissy-Saint-Léger et Cergy-Le-Haut/Poissy , en raison d'un train en panne à Nogent-sur-Marne.#RERA
# ----
# Le train actuellement à Gare de Lyon et en direction du Vésinet-Le Pecq stationne en raison de l'actionnement d'un signal d'alarme. #RERA
# ----
# Le train actuellement à Sartrouville et en direction de Boissy-Saint-Léger stationne en raison d'une panne. #RERA
# ----
# Le train actuellement à Lognes et en direction de Marne-la-Vallée–Chessy stationne en raison de l'intervention du conducteur. #RERA
# ----
#  La gare de Marne-la-Vallée–Chessy est fermée, en raison d'un bagage oublié. #RERA
# ----
# Le train actuellement à Rueil-Malmaison et en direction de Saint-Germain-en-Laye  stationne en raison d'un incident nécessitant l'intervention des agents. #RERA
# ----
# [#MardiConseil] Vous souhaitez connaitre l'horaire de passage de votre train ? Les fiches horaires sont aussi à votre disposition pour les dates de votre choix à tout moment sur le blog du #RERA ici
# ----
# Le trafic est perturbé de Marne la Vallée Chessy vers Rueil-Malmaison, en raison d'un incident technique sur un train à Marne-la-Vallée – Chessy.  #RERA
# ----
# Le trafic  perturbé de La Défense vers Marne-la-Vallée Chessy et Boissy St Léger , en raison d'une altercation entre voyageurs à Gare de Lyon. #RERA
# ----
# Le trafic est perturbé de La Défense vers Marne-la-Vallée Chessy et Boissy St Léger , en raison d'une altercation entre voyageurs à Gare de Lyon. #RERA
# ----
# Le train actuellement à Châtelet–Les Halles et en direction de Marne-la-Vallée–Chessy stationne en raison d'un incident voyageur. #RERA
# ----
#  Le trafic est perturbé de Nanterre–Préfecture vers Poissy, en raison d'un bagage oublié à Poissy. #RERA
# ----
# [#NouvelArticle ] Que faire en cas de malaise ? Quels comportements adopter pour éviter un accident grave ? Comment signaler une situation inquiétante ? Apprenez les bons réflexes à avoir dans notre nouvel article du blog #RERA ici
# ----
# Le train actuellement à Gare de Lyon et en direction de Marne-la-Vallée–Chessy stationne en raison de l'actionnement d'un signal d'alarme. #RERA
# ----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[210], line 19
#      17 print("----")
#      18 is_problem_user = input(f"Est-ce un problème pour la ligne {i} (oui/non) ? ({is_problem}) : ")
# ---> 19 label_user = input(f"Entrez le label pour la ligne {i} {label} ")
#      21 df_f.at[i, 'is_problem'] = is_problem_user.lower() == 'oui'
#      22 df_f.at[i, 'label'] = label_user
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1191, in Kernel.raw_input(self, prompt)
#    1189     msg = "raw_input was called, but this frontend does not support input requests."
#    1190     raise StdinNotImplementedError(msg)
# -> 1191 return self._input_request(
#    1192     str(prompt),
#    1193     self._parent_ident["shell"],
#    1194     self.get_parent("shell"),
#    1195     password=False,
#    1196 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1234, in Kernel._input_request(self, prompt, ident, parent, password)
#    1231 except KeyboardInterrupt:
#    1232     # re-raise KeyboardInterrupt, to truncate traceback
#    1233     msg = "Interrupted by user"
# -> 1234     raise KeyboardInterrupt(msg) from None
#    1235 except Exception:
#    1236     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
df_f = pd.read_csv("df_f.csv")
df_f.replace("alrme", "alarme", inplace=True)
df_f.replace("train_panne", "panne_train", inplace=True)
df_f.head()
# Out:
#   tweet_type          time_posted  \
# 0     Normal  2024-08-03 18:47:13
# 1    Réponse  2024-08-03 19:09:26
# 2    Réponse  2024-08-03 19:53:27
# 3     Normal  2024-08-03 14:35:52
# 4    Réponse  2024-08-03 14:42:08
#
#                                              content  associated_tweet_id  \
# 0   Le trafic est perturbé de Poissy vers Nanterr...                  NaN
# 1  Le trafic est perturbé de Nanterre - Préfectur...                  NaN
# 2   Le trafic est rétabli de Nanterre–Préfecture ...                  NaN
# 3   Le train stationne à Gare de Lyon en directio...                  NaN
# 4   Le train est reparti de Gare de Lyon en direc...                  NaN
#
#    comments  retweets  likes  views             extraction_date  \
# 0         3         4      7   9272  2024-08-04 11:30:25.868093
# 1         2         0      1   6232  2024-08-04 11:30:37.644244
# 2         1         0      3   4170  2024-08-04 11:30:37.842704
# 3         6         1      6   9031  2024-08-04 11:30:38.271172
# 4         1         0      3   1768  2024-08-04 11:30:49.952408
#
#                                tweet_id  ...  \
# 0  e392794b-bde4-47b6-8c06-b4a44fcecbbe  ...
# 1  e392794b-bde4-47b6-8c06-b4a44fcecbbe  ...
# 2  e392794b-bde4-47b6-8c06-b4a44fcecbbe  ...
# 3  76b5ed98-bfa0-4636-a87a-5c4540151eaf  ...
# 4  76b5ed98-bfa0-4636-a87a-5c4540151eaf  ...
#
#                                 content_removed_gare  \
# 0   le trafic est perturbe de  vers  en raison d ...
# 1  le trafic est perturbe de  vers  en raison d u...
# 2   le trafic est retabli de  vers  incident d ex...
# 3   le train stationne a  en direction de  en rai...
# 4   le train est reparti de  en direction de  en ...
#
#                                   content_removed_sw  \
# 0  ['trafic', 'perturbe', 'raison', 'incident', '...
# 1  ['trafic', 'perturbe', 'raison', 'incident', '...
# 2  ['trafic', 'retabli', 'incident', 'exploitation']
# 3  ['stationne', 'raison', 'actionnement', 'signa...
# 4  ['reparti', 'repercussion', 'actionnement', 's...
#
#                                 content_cleand_str  \
# 0     trafic perturbe raison incident exploitation
# 1     trafic perturbe raison incident exploitation
# 2             trafic retabli incident exploitation
# 3      stationne raison actionnement signal alarme
# 4  reparti repercussion actionnement signal alarme
#
#                                          word_counts  \
# 0  Counter({'trafic': 1, 'perturbe': 1, 'raison':...
# 1  Counter({'trafic': 1, 'perturbe': 1, 'raison':...
# 2  Counter({'trafic': 1, 'retabli': 1, 'incident'...
# 3  Counter({'stationne': 1, 'raison': 1, 'actionn...
# 4  Counter({'reparti': 1, 'repercussion': 1, 'act...
#
#                                        bigram_counts  \
# 0  Counter({('trafic', 'perturbe'): 1, ('perturbe...
# 1  Counter({('trafic', 'perturbe'): 1, ('perturbe...
# 2  Counter({('trafic', 'retabli'): 1, ('retabli',...
# 3  Counter({('stationne', 'raison'): 1, ('raison'...
# 4  Counter({('reparti', 'repercussion'): 1, ('rep...
#
#                                       trigram_counts is_problem  \
# 0  Counter({('trafic', 'perturbe', 'raison'): 1, ...       True
# 1  Counter({('trafic', 'perturbe', 'raison'): 1, ...       True
# 2  Counter({('trafic', 'retabli', 'incident'): 1,...       True
# 3  Counter({('stationne', 'raison', 'actionnement...       True
# 4  Counter({('reparti', 'repercussion', 'actionne...       True
#
#                   date engagement         label
# 0  2024-08-03 18:47:13   0.150992  exploitation
# 1  2024-08-03 19:09:26   0.048139           NaN
# 2  2024-08-03 19:53:27   0.095923           NaN
# 3  2024-08-03 14:35:52   0.143949        alarme
# 4  2024-08-03 14:42:08   0.226244           NaN
#
# [5 rows x 21 columns]

# %%
last_index = df_f["label"].dropna().index[-1]

for i, row in df_f.iterrows():
    if i < last_index and isinstance(row["label"], float):
        df_f.at[i, 'label'] = 'no_label'

# %%
valid = df[0:last_index-1]
valid = valid[valid['tweet_type']=='Normal']

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder




vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(valid['content_cleand_str'])

# Convert sparse matrix to dense array
X = X.toarray()

# Encode the labels (y) using OneHotEncoder
label_encoder = OneHotEncoder()
y = label_encoder.fit_transform(valid[['label']]).toarray()

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train a logistic regression model
model = RandomForestClassifier(n_estimators=100, max_depth=60)
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.8085106382978723

# %% [markdown]
# ## Classification zero shot

# %%
tweet_incidents = df_f[df_f['is_problem']==True]
tweet_normaux_incidents = tweet_incidents[tweet_incidents['tweet_type']=='Normal']
tweet_normaux_incidents.loc[0, 'content']
# Out:
# " Le trafic est perturbé de Poissy vers Nanterre - Préfecture , en raison d'un incident d'exploitation à Poissy #RERA"

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification", model="MoritzLaurer/mDeBERTa-v3-base-mnli-xnli")
sequence_to_classify = tweet_normaux_incidents.loc[0, 'content']
candidate_labels = [
    "exploitation",
    "alarme",
    "agent",
    "bagage",
    "sur_voie",
    "malaise",
    "conducteur",
    "technique",
    "inondation",
    "arbre",
    "altercation",
    "aff_voie",
    "ferm_porte",
    "train_panne",
    "accident_pers",
    "panne_elec",
    "signalisation",
    "panne_train",
    "voyageur",
    "panne_porte",
    "police",
    "sortie_garage",
    "catenaire",
    "ajustement_interv",
    "rallong_chantier",
    "degradation"
]
output = classifier(sequence_to_classify, candidate_labels, multi_label=False)
print(output)
# Out:
# {'sequence': " Le trafic est perturbé de Poissy vers Nanterre - Préfecture , en raison d'un incident d'exploitation à Poissy #RERA", 'labels': ['exploitation', 'altercation', 'sur_voie', 'accident_pers', 'alarme', 'panne_porte', 'ajustement_interv', 'rallong_chantier', 'agent', 'voyageur', 'signalisation', 'ferm_porte', 'degradation', 'police', 'malaise', 'aff_voie', 'catenaire', 'technique', 'conducteur', 'arbre', 'panne_train', 'train_panne', 'sortie_garage', 'bagage', 'panne_elec', 'inondation'], 'scores': [0.4789467453956604, 0.2436993271112442, 0.11318320035934448, 0.01874450594186783, 0.01827421598136425, 0.013358556665480137, 0.011777183972299099, 0.011108889244496822, 0.010000101290643215, 0.00907270610332489, 0.007801157422363758, 0.007282556034624577, 0.0067369709722697735, 0.0059247915633022785, 0.005436530336737633, 0.00538730388507247, 0.005326096434146166, 0.00505521846935153, 0.003938476089388132, 0.00374523364007473, 0.003055374138057232, 0.0027391952462494373, 0.0026873776223510504, 0.002587436931207776, 0.0025553195737302303, 0.0015755337662994862]}

# %% [markdown]
# ## Classification manuelle (aidé de vectorisation)
# Savoir si un tweet relate un incident est une chose, trouver la nature de l'incident en est une autre. Les typologies de problèmes sont assez délimitées et observable, en prenant les cas de bases et en y associant les mots les plus courantes il est possible de former des catégories principales. Ensuite, de manière itérative en regardant les tweets d'incidents non classifiés on peut créer ou étendre une typologie...

# %%
labels = {
"bagage oublie": ["bagage oublie"],
"signal alarme": ["actionnement signal alarme", "signal alarme"],
"signalisation" : ['panne signalisation', 'incident signalisation'],
"porte" : ['panne porte', 'panne portes', 'gene fermeture portes'],
"panne electrique": ['panne electrique'],
'incident exploitation': ['difficultés exploitation', 'difficultes exploitation', 'incident exploitation', 'incident explitation'],
"incident technique": ['incident technique', 'intervention services techniques'],
"intervention personnel": ['intervention agents', 'intervention conducteur', 'forces ordre', 'intervention equipes techniques'],
"voyageur": ['accident grave personne', 'acte malveillance', 'malaise voyageur', 'malaises voyageurs', 'incident voyageur', 'altercation voyageurs', 'bagarre voyageurs', 'degradation volontaire'],
"voies": ['personne voies', 'arbre voies', 'incident affectant voie', 'personnes voies', 'incident affcetant voie', 'voie occupee', 'animal voies'],
"catenaires" : ['chute catenaires', 'rupture catenaire', 'chute catenaire'],
"divers" : ['inondations', "incident informatique", "sortie garage"],
"ajustement intervalle" : ['ajustement intervalle'],
"degagement fumee": ['degagement fumee'],
"regulation":['mesures regulation'],
"mesure securite": ['mesure securite', 'mesures securite'],
"police": ['demande prefecture police', 'demande prefpolice', 'ordre prefecture police'],
"chantier": ['rallongement duree chantier', 'fin tardive chantier'],
"affluence exceptionnelle": ['affluence exceptionnelle'],
"panne train" : ["panne de train", "panne train", "panne"],
}

# %%
df_f[(df_f['is_problem']==True) & (df_f['tweet_type']=='Normal')].shape
# Out:
# (828, 22)

# %%
df_f ['label'] = ""
for index, row in df_f.iterrows():
    #if row['is_problem']==True and row['tweet_type']=='Normal':
    if row['tweet_type']=='Normal':
        text = row['content_cleand_str']
        label_associe = []
        for label in labels:
            for word in labels[label]:
                if word in text:
                    text = text.replace(word, '')
                    label_associe.append(label)
                    
        
        df_f.at[index, 'label'] = ",".join(label_associe)

# %%
df_f['len_label'] = df_f['label'].apply(lambda x: 0 if x=="" else len(x.split(',')))

# %%
df_f[df_f['tweet_type']=="Normal"].groupby('len_label').size()
# Out:
# len_label
# 0    103
# 1    820
# 2      8
# dtype: int64

# %%
df_f[(df_f['tweet_type']=="Normal") & (df_f['len_label']==0)][['content', 'content_cleand_str']].values
# Out:
#        ["[#MardiConseil] C'est l'été ! La forte affluence et les hautes températures sont omniprésents ! Les trains du #RERA sont équipés de la ventilation réfrigérée. Les détails de son fonctionnement sont expliqués ci-dessous ",
#         'mardiconseil ete forte affluence hautes temperatures omnipresents equipes ventilation refrigeree details fonctionnement expliques ci dessous'],
#        ["[Hausse des températures] : Pensez à vous hydrater avant votre arrivée en gare et emportez de l'eau pour votre trajet. Restez attentifs envers les autres voyageurs et n'hésitez pas à solliciter nos agents ! #RERA",
#         'hausse temperatures pensez hydrater avant arrivee emportez eau trajet restez attentifs envers autres voyageurs hesitez solliciter agents'],
#        ["[Fortes chaleurs ] : Pensez à vous hydrater avant votre arrivée en gare et emportez de l'eau pour votre trajet. Restez attentifs envers les autres voyageurs et n'hésitez pas à solliciter les agents #RERA.",
#         'fortes chaleurs pensez hydrater avant arrivee emportez eau trajet restez attentifs envers autres voyageurs hesitez solliciter agents'],
#        ["[#PARIS2024] Pour cette journée spéciale, #LaTeamCM du #RERA se mobilise et sera à votre disposition exceptionnellement jusqu'à minuit aujourd'hui ! N'hésitez pas à nous solliciter ",
#         'cette journee speciale lateamcm mobilise disposition exceptionnellement jusqu minuit aujourd hui hesitez solliciter'],
#        ["[#MardiConseil] Les Jeux de Paris 2024 approchent et vous souhaitez anticiper vos déplacements ? Retrouvez les informations nécessaires à travers l'article ci-dessous. #RERA",
#         'mardiconseil jeux approchent souhaitez anticiper deplacements retrouvez informations necessaires travers article ci dessous'],
#        ['#JO2024 Vendredi 19 juillet 2024, la flamme olympique  sera de passage à proximité de la gare #RERA de Cergy-Préfecture ! Prévoyez des modifications de desserte des bus urbains. Vous retrouverez plus de détails sur le site Île-de-France Mobilités et auprès de nos agents.',
#         'jo vendredi juillet flamme olympique passage proximite prefecture prevoyez modifications desserte bus urbains retrouverez plus details site ile france mobilites aupres agents'],
#        ['[#NouvelArticle ] Vous avez des sujets que vous voulez voir sur notre blog ? Dites-nous tout dans le sondage présent dans notre nouvel article du blog #RERA ici ',
#         'nouvelarticle sujets voulez voir blog dites tout sondage present nouvel article blog ici'],
#        ["[#JeudiPhoto ] Accrochez-vous, le MS61 arrive en gare ! Sauriez-vous deviner de quelle gare il s'agit ? #RERA",
#         'jeudiphoto accrochez ms arrive sauriez deviner quelle agit'],
#        [" Ces #lapins ont été retrouvés hier soir en gare #RERA de Châtelet–Les Halles autour de 19 heures. Nous recherchons leur propriétaire ! N'hésitez pas à nous contacter si vous avez des informations, et RT pour diffuser ! ",
#         'lapins ete retrouves hier soir autour heures recherchons proprietaire hesitez contacter si informations rt diffuser'],
#        ['[#NouvelArticle ] Vous empruntez les transports en commun durant cet été ? Retrouvez nos conseils pratiques pour des trajets sereins dans notre nouvel article du blog #RERA ici ',
#         'nouvelarticle empruntez transports commun durant cet ete retrouvez conseils pratiques trajets sereins nouvel article blog ici'],
#        ['[#JeudiPhoto ] Retour en 1964 ! Sauriez-vous deviner de quelle gare provient cette vue ? #RERA',
#         'jeudiphoto retour sauriez deviner quelle provient cette vue'],
#        [' Un train stationne à Chatelet les Halles en direction de Cergy/Poissy #RERA',
#         ''],
#        ['[#Animation] Rendez-vous en gare #RERA d\'Auber avec nos agents pour la "journée des gestes qui sauvent" jusqu\'à 20 heures. Devenez incollable sur les gestes de sécurité à adopter dans les transports en commun !',
#         'animation rendez agents journee gestes sauvent jusqu heures devenez incollable gestes securite adopter transports commun'],
#        ["[#MardiConseil] Vous souhaitez connaitre l'horaire de passage de votre train ? Les fiches horaires sont aussi à votre disposition pour les dates de votre choix à tout moment sur le blog du #RERA ici ",
#         'mardiconseil souhaitez connaitre horaire passage fiches horaires aussi disposition dates choix tout moment blog ici'],
#        ['[#NouvelArticle ] Que faire en cas de malaise ? Quels comportements adopter pour éviter un accident grave ? Comment signaler une situation inquiétante ? Apprenez les bons réflexes à avoir dans notre nouvel article du blog #RERA ici ',
#         'nouvelarticle faire cas malaise quels comportements adopter eviter accident grave comment signaler situation inquietante apprenez bons reflexes avoir nouvel article blog ici'],
#        ["[Animation ] À l'occasion de la #MarcheDesFiertes 2024, retrouvez nos agents en gare de Châtelet les Halles de 11H30 et 14H30. Au programme : distribution de bracelets arc-en-ciel, maquillage et photos avec Serge le lapin . À tout à l'heure !",
#         'animation occasion marchedesfiertes retrouvez agents programme distribution bracelets arc ciel maquillage photos serge lapin tout'],
#        ['[#Travaux ] Retrouvez les détails des travaux de soirée prévus en Juillet-Août entre Nanterre–Préfecture et Cergy–Le Haut • Poissy sur le blog du #RERA ici ',
#         'travaux retrouvez details travaux soiree prevus juillet aout blog ici'],
#        ['Et vous vous lisez quoi à bord du #RERA ? #VendrediLecture',
#         'lisez quoi bord vendredilecture'],
#        ["[#JeudiPhoto ]  Voici une ancienne photo de la gare #RERA de Boissy-Saint-Léger. Sauriez-vous deviner de quelle année date ce cliché ?  (un indice : c'est vieux)",
#         'jeudiphoto voici ancienne photo sauriez deviner quelle annee date cliche indice vieux'],
#        ['[Animation] Le 3 juillet la #RATP organise la Journée des Gestes qui sauvent. Nos agents vous attendent à la gare RER d’Auber de 9h à 20h pour partager avec vous les bons réflexes à avoir dans les transports.\nhttps://ratp.fr/la-journee-des-gestes-qui-sauvent…',
#         'animation juillet ratp organise journee gestes sauvent agents attendent rer partager bons reflexes avoir transports https ratp fr journee gestes sauvent'],
#        ['[Nouvel article ] Avant les vacances, prenez le pouvoir et souscrivez au forfait imagine R ! C’est rapide et en ligne. \nRetrouvez toutes les informations sur le blog du #RERA ',
#         'nouvel article avant vacances prenez pouvoir souscrivez forfait imagine r cest rapide retrouvez toutes informations blog'],
#        ["[#MardiConseil] N'oubliez pas de vous hydrater en cette journée ensoleillée ! Une bouteille d'eau à portée de main vous permettra de rester frais pendant votre trajet. . #RERA",
#         'mardiconseil oubliez hydrater cette journee ensoleillee bouteille eau portee main permettra rester frais pendant trajet'],
#        ["[Animation] Dans le cadre du réaménagement de la salle d'accueil de la gare de Marne La Vallée – Chessy, nos agents vous propose d'échanger autour d'un café. À tout de suite !",
#         'animation cadre reamenagement salle accueil agents propose echanger autour cafe tout'],
#        ['[#FêtedelaMusique ] Votre #RERA fonctionne toute la nuit ! Retrouvez toutes les infos ainsi que le planning des animations sur notre blog \nhttps://rera-leblog.fr/fete-de-la-musique-2024-avec-vous-au-bout-de-la-nuit/…',
#         'fetedelamusique fonctionne toute nuit retrouvez toutes infos ainsi planning animations blog https leblog fr fete musique bout nuit'],
#        ["[#NouvelArticle ] Les trains courts surchargés en soirée, c'est fini ! Découvrez la nouvelle offre de soirée sur la ligne A dans le nouvel article du blog #RERA ici ",
#         'nouvelarticle courts surcharges soiree fini decouvrez nouvelle offre soiree nouvel article blog ici'],
#        ['Ça par exemple on a liké... ', 'ca exemple like'],
#        ['[#Tchat ] «L’infrastructure sur la branche Cergy ne nous permet pas de mettre plus de 10 trains par heure. Il n’y a donc pas de possibilité de rajouter des trains. C’est pour cela que IDFM a commandé une grande étude, dont les résultats seront connus mi-2025, pour pouvoir\nVoir plus',
#         'tchat linfrastructure branche permet mettre plus ny donc possibilite rajouter cest idfm commande grande etude dont resultats connus mi pouvoir voir plus'],
#        ['[#Tchat ] «On va avoir l’extension du pilotage automatique jusqu’à la gare de Noisy-Champs. Cette extension est prévue à la fin de l’année 2024.»',
#         'tchat va avoir lextension pilotage automatique jusqua cette extension prevue fin lannee'],
#        ["[#Tchat ] Nos directeurs s'installent, vous pouvez venir poser vos questions en direct sur le blog \nhttps://rera-leblog.fr/tchat-en-direct-avec-les-directeurs-ratp-et-sncf-de-la-ligne-a/…",
#         'tchat directeurs installent pouvez venir poser questions direct blog https leblog fr tchat direct directeurs ratp sncf'],
#        ["[#Tchat] Rappel : Vous pouvez encore poser vos questions pour le tchat aux directeurs RATP et SNCF de la ligne du #RERA ils y répondront aujourd'hui à 12h. RDV sur le blog ",
#         'tchat rappel pouvez encore poser questions tchat directeurs ratp sncf repondront aujourd hui rdv blog'],
#        [" Le trafic est rétabli sur l'ensemble de la ligne. #RERA",
#         'retabli'],
#        ['[Nouvel article ] Soyez prudents sur les escaliers mécaniques . Découvrez nos conseils pour votre sécurité à travers cet article sur le blog du #RERA.',
#         'nouvel article prudents escaliers mecaniques decouvrez conseils securite travers cet article blog'],
#        ['[#Tchat] Rappel : Il est encore temps de poser vos questions pour le tchat aux directeurs RATP et SNCF de la ligne du #RERA qui y répondront en direct ce lundi. RDV sur le blog ',
#         'tchat rappel encore temps poser questions tchat directeurs ratp sncf repondront direct lundi rdv blog'],
#        ['[#JeudiPhoto ] Pouvez-vous deviner où ces photos fleuries ont été prises ? #RERA',
#         'jeudiphoto pouvez deviner photos fleuries ete prises'],
#        ['[Nouvel article ] La gestion des déchets organiques : une priorité pour un RER A propre et agréable. Découvrez comment nos équipes et vous, voyageurs, pouvez faire la différence ensemble !  #RERA',
#         'nouvel article gestion dechets organiques priorite rer propre agreable decouvrez comment equipes voyageurs pouvez faire difference'],
#        ['En effet, s’il vous est déjà arrivé par mégarde de faire tomber un écouteur sur les voies, ou tout autre objet, un agent en gare peut le récupérer ! \nTout cela en veillant évidemment à respecter des procédures destinées à assurer la sécurité des voyageurs présents sur les quais\nVoir plus',
#         'effet sil deja arrive megarde faire tomber ecouteur voies tout objet agent peut recuperer tout veillant evidemment respecter procedures destinees assurer securite voyageurs presents quais voir plus'],
#        ['[#MardiConseil] Pour voyager en sécurité dans le #RERA, tenez-vous fermement ! Agrippez-vous, déplacez-vous avec précaution, gardez vos affaires en place, écoutez les annonces sonores et adoptez une posture stable. Bonne route ! ',
#         'mardiconseil voyager securite tenez fermement agrippez deplacez precaution gardez affaires place ecoutez annonces sonores adoptez posture stable bonne route'],
#        ['[#Tchat]  Rappel : Vous pouvez encore poser vos questions pour le tchat aux directeurs RATP et SNCF de la ligne du #RERA. RDV sur le blog ',
#         'tchat rappel pouvez encore poser questions tchat directeurs ratp sncf rdv blog'],
#        ['Le trafic est perturbé à Nanterre – Préfecture en direction de Marne-la-Vallée – Chessy. Nous vous présentons nos excuses et nos agents sont mobilisés pour un retour à la normale au plus vite #RERA',
#         'presentons excuses agents mobilises retour normale plus vite'],
#        ["[Nouvel article ] Chercher son passe navigo au fond de son sac, c'est fini\u202f! Découvrez comment faire pour l'installer dès maintenant sur vos appareils connectés avec le nouvel article du blog #RERA https://rera-leblog.fr/votre-telephone-devient-votre-passe-navigo/…",
#         'nouvel article chercher passe navigo fond sac fini decouvrez comment faire installer maintenant appareils connectes nouvel article blog https leblog fr telephone devient passe navigo'],
#        ["[#JeudiPhoto ] Époque des coiffures improbables et des cols pelle à tarte en gare du #RERA ! Flash-back dans les années 80 : sortez vos walkmans, rembobinez la cassette et lancez votre meilleur son d'Indochine ",
#         'jeudiphoto epoque coiffures improbables cols pelle tarte flash back annees sortez walkmans rembobinez cassette lancez meilleur indochine'],
#        ['[#Tchat ] Des questions à propos de la ligne A et son avenir ? Venez poser vos questions aux directeurs de la ligne #RERA lors de notre prochain tchat qui se déroulera le lundi 17 juin. ',
#         'tchat questions propos avenir venez poser questions directeurs lors prochain tchat deroulera lundi juin'],
#        ["Fin d'incident. Le trafic reprend normalement sur l'ensemble du #RERA",
#         'fin incident reprend normalement'],
#        ['Fin de manifestations, la station Charles-de-Gaulle-Étoile est rouverte #RERA',
#         'fin manifestations station rouverte'],
#        ["[Mouvement social ] En raison d'un mouvement social, le trafic sera perturbé le vendredi 31 mai 2024 sur la ligne. #RERA",
#         'mouvement social mouvement social vendredi mai'],
#        ['[#JeudiPhoto ] Sauriez-vous deviner de quelle année date ces jolis clichés en gare #RERA de Nogent-sur-Marne ?',
#         'jeudiphoto sauriez deviner quelle annee date jolis cliches'],
#        ["[Mouvement social ] En raison d'un mouvement social, le trafic sera perturbé le vendredi 31 mai 2024 sur la ligne. #RERA",
#         'mouvement social mouvement social vendredi mai'],
#        ['[Nouvel article ] Émilie, agente GPSR : « Nos missions : sécurisation, contrôle et information voyageurs » Découvrez son portrait sur le blog du #RERA',
#         'nouvel article emilie agente gpsr missions securisation controle information voyageurs decouvrez portrait blog'],
#        ['[Nouvel article ] Traverser les voies ? Même pas en rêve ! Découvrez toutes les informations dans le nouvel article du blog du #RERA',
#         'nouvel article traverser voies meme reve decouvrez toutes informations nouvel article blog'],
#        ['[Mouvement social] En raison d’un mouvement social le mardi 21 mai 2024, le trafic est très perturbé entre Nanterre–Préfecture et Cergy–Le Haut • Poissy. Le trafic est normal sur le reste de la ligne.',
#         'mouvement social dun mouvement social mardi mai tres normal'],
#        ['[Nouvel article ] Vous aviez des questions sur les derniers travaux ? On vous explique tout dans le nouvel article du blog #RERA',
#         'nouvel article questions derniers travaux explique tout nouvel article blog'],
#        ["#VendrediLecture La procédure de rechargement de votre Passe Navigo n'aura plus de secret pour vous grâce à cet article du blog #RERA !",
#         'vendredilecture procedure rechargement passe navigo plus secret grace cet article blog'],
#        ['[Mouvement social] Mardi 21 mai – Mouvement social\nLe trafic du RER A pourrait être perturbé entre Nanterre–Préfecture et Cergy–Le Haut • Poissy.',
#         'mouvement social mardi mai mouvement social rer pourrait etre'],
#        ["[#JeudiPhoto ] Ambiance 70's dans une des grandes gares du #RERA L'avez-vous reconnue ? ",
#         'jeudiphoto ambiance grandes gares reconnue'],
#        ['[Nouvel article ] Besoin de contacter un de nos agents  ? On vous explique tout dans le nouvel article du blog #RERA ',
#         'nouvel article besoin contacter agents explique tout nouvel article blog'],
#        ["La #TeamCM du #RERA vous souhaite une excellente journée ! N'hésitez pas à nous solliciter ",
#         'teamcm souhaite excellente journee hesitez solliciter'],
#        ['[#TravauxRERA ]  Dernier trains permettant de poursuivre le trajet en RER A au-delà de la zone interrompue en direction de :\n\n• Saint-Germain-en-Laye : 00:02 à Châtelet–Les Halles\n• Paris • Boissy-Saint-Léger • Marne-la-Vallée–Chessy : 23:34 à Saint-Germain-en-Laye',
#         'travauxrera dernier permettant poursuivre trajet rer dela zone interrompue'],
#        ['[#TravauxRERA ]  Dernier trains permettant de poursuivre le trajet en RER A au-delà de la zone interrompue en direction de :\n\n• Saint-Germain-en-Laye : 00:02 à Châtelet–Les Halles\n• Paris • Boissy-Saint-Léger • Marne-la-Vallée–Chessy : 23:34 à Saint-Germain-en-Laye',
#         'travauxrera dernier permettant poursuivre trajet rer dela zone interrompue'],
#        ['[#TravauxRERA ]  Dernier trains permettant de poursuivre le trajet en RER A au-delà de la zone interrompue en direction de :\n\n• Saint-Germain-en-Laye : 00:05 à Châtelet–Les Halles\n• Paris • Boissy-Saint-Léger • Marne-la-Vallée–Chessy : 23:29 à Saint-Germain-en-Laye',
#         'travauxrera dernier permettant poursuivre trajet rer dela zone interrompue'],
#        ['[#TravauxRERA ]  Dernier trains permettant de poursuivre le trajet en RER A au-delà de la zone interrompue en direction de :\n\n• Saint-Germain-en-Laye : 00:02 à Châtelet–Les Halles\n• Paris • Boissy-Saint-Léger • Marne-la-Vallée–Chessy : 23:34 à Saint-Germain-en-Laye',
#         'travauxrera dernier permettant poursuivre trajet rer dela zone interrompue'],
#        ['[#TravauxRERA ]  Dernier trains permettant de poursuivre le trajet en RER A au-delà de la zone interrompue en direction de :\n\n• Saint-Germain-en-Laye : 00:02 à Châtelet–Les Halles\n• Paris • Boissy-Saint-Léger • Marne-la-Vallée–Chessy : 23:34 à Saint-Germain-en-Laye',
#         'travauxrera dernier permettant poursuivre trajet rer dela zone interrompue'],
#        ["[#Travaux ] Rappel : dès demain et jusqu'à dimanche inclus, des travaux auront lieu entre Le Vésinet-Centre et Rueil-Malmaison. Aucun train ne circulera entre ces gares. Des bus de substitution seront à votre disposition. Tous les détails sur le blog du #RERA\nVoir plus",
#         'travaux rappel demain jusqu dimanche inclus travaux lieu aucun circulera gares bus substitution disposition tous details blog voir plus'],
#        ['[Nouvel article ] Le RER E rejoint le RER A en gare de La Défense ! Apprenez-en plus dans le nouvel article du blog du #RERA',
#         'nouvel article rer e rejoint rer apprenez plus nouvel article blog'],
#        ['[#Travaux] Retrouvez les détails des travaux de soirée prévus en Mai-Juin dans le calendrier travaux disponible sur le blog du #RERA ici ',
#         'travaux retrouvez details travaux soiree prevus mai juin calendrier travaux disponible blog ici'],
#        ['[Nouvel article ] Comme tout un chacun, nos agents méritent le respect : découvrez-en plus dans le nouvel article du blog du #RERA ',
#         'nouvel article comme tout chacun agents meritent respect decouvrez plus nouvel article blog'],
#        ['Et vous, quelle lecture anime actuellement votre trajet sur le #RERA ? #VendrediLecture',
#         'quelle lecture anime trajet vendredilecture'],
#        ["[#JeudiPhoto ] Petit bond dans le temps ! Sauriez-vous deviner l'année de la prise de cette vue en gare de Champigny ? #RERA",
#         'jeudiphoto petit bond temps sauriez deviner annee prise cette vue'],
#        ["[#Tchat ] En cas d’incident, une information locale est diffusée dans les 3min suivant le début de la perturbation. Au plus tard 12min après le début de l’incident, les médias distants sont renseignés. Sur X, un tweet est publié en moyenne 5min après le début d'incident. #RERA",
#         'tchat cas dincident information locale diffusee min suivant debut perturbation plus tard min apres debut lincident medias distants renseignes x tweet publie moyenne min apres debut incident'],
#        ['[#Tchat ] Le rôle du CCU est aussi de donner le maximum d’informations aux conducteurs des trains pour qu’ils puissent à leur tour informer les voyageurs des incidents en cours. #RERA',
#         'tchat role ccu aussi donner maximum dinformations conducteurs quils puissent tour informer voyageurs incidents cours'],
#        ['[#Tchat ]  Le sens de la création du CCU et de la réunion des acteurs est d’améliorer la gestion des incidents et donc de diminuer leur impact autant que possible pour les voyageurs, et de mieux vous informer. #RERA',
#         'tchat sens creation ccu reunion acteurs dameliorer gestion incidents donc diminuer impact autant possible voyageurs mieux informer'],
#        ['[#Tchat ] Le nouveau CCU nous permet d’afficher en temps réel la visualisation des quais et de la relève conducteur, facilitant ainsi la prise de décision par rapport à la gestion de la convergence. #RERA',
#         'tchat nouveau ccu permet dafficher temps reel visualisation quais releve conducteur facilitant ainsi prise decision rapport gestion convergence'],
#        ['[#Tchat ] Le nouveau CCU permet de regrouper sur un seul mur d’images de 18 mètres toutes les informations de circulation des trains sur l’ensemble de la ligne (RATP et SNCF), ce qui n’était pas le cas dans l’ancien CCU. #RERA',
#         'tchat nouveau ccu permet regrouper seul mur dimages metres toutes informations circulation lensemble ratp sncf netait cas lancien ccu'],
#        ['[#Tchat ]  Le nouveau CCU permet d’améliorer la cohérence et la rapidité des informations que nous diffusons auprès des voyageurs. #RERA',
#         'tchat nouveau ccu permet dameliorer coherence rapidite informations diffusons aupres voyageurs'],
#        ["[#Tchat ] Le tchat sur l'inauguration du nouveau CCU du #RERA commence d'ici quelques instants ! Rendez-vous à 12:15 sur le blog. ",
#         'tchat tchat inauguration nouveau ccu commence ici quelques instants rendez blog'],
#        ["[#Tchat ] L'inauguration du nouveau CCU #RERA s'est déroulée cet après-midi ! Découvrez en vidéo la nouvelle salle et posez vos questions sur le blog, nous y répondrons en direct demain à partir de 12:15 lors d'un tchat. ",
#         'tchat inauguration nouveau ccu deroulee cet apres midi decouvrez video nouvelle salle posez questions blog repondrons direct demain partir lors tchat'],
#        ["[#Tchat ] En quoi le nouveau CCU du #RERA est-il plus ergonomique ? Vous pouvez d'ores et déjà poser vos questions sur le blog, nous y répondrons en direct le 26 avril à partir de 12:15 lors d'un tchat. ",
#         'tchat quoi nouveau ccu plus ergonomique pouvez ores deja poser questions blog repondrons direct avril partir lors tchat'],
#        ["[#Tchat] Partons à la découverte des nouveaux outils du CCU du #RERA. Vous pouvez d'ores et déjà poser vos questions sur le blog, nous y répondrons en direct le 26 avril à partir de 12:15 lors d'un tchat. ",
#         'tchat partons decouverte nouveaux outils ccu pouvez ores deja poser questions blog repondrons direct avril partir lors tchat'],
#        ["[#Travaux] Dans le cadre d'opérations d'entretien des voies, le trafic du #RERA est interrompu jusqu'au 26 avril, tous les soirs à partir de 22h00, entre Cergy–Le Haut • Poissy et Nanterre–Préfecture. Des bus de remplacement sont mis en place ",
#         'travaux cadre operations entretien voies jusqu avril tous soirs partir bus remplacement mis place'],
#        ["Pendant ce temps là, dans l'un de nos trains, deux pigeons flirtent #RERAmour ",
#         'pendant temps deux pigeons flirtent reramour'],
#        ["[#Tchat ] Avant de partir à la découverte du nouveau CCU du #RERA, retour sur la longue histoire de la « tour de contrôle » de la ligne. Vous pouvez d'ores et déjà poser vos questions sur le blog, nous y répondrons en direct le 26 avril à partir de 12:15 lors d'un tchat. \nVoir plus",
#         'tchat avant partir decouverte nouveau ccu retour longue histoire tour controle pouvez ores deja poser questions blog repondrons direct avril partir lors tchat voir plus'],
#        ["[Retour sur incident ] Que s'est-il passé sur votre ligne la journée du 17 avril et du 18 avril matin ? Nous vous expliquons tout cela ici sur le blog du #RERA ",
#         'retour incident passe journee avril avril matin expliquons tout ici blog'],
#        ["Ce mercredi 17 avril à 05:15, le premier train de voyageurs au départ de Marne-la-Vallée–Chessy s'est immobilisé peu après la gare de Val d'Europe en raison d'une coupure d'électricité constatée par le conducteur.",
#         'mercredi avril premier voyageurs depart immobilise peu apres coupure electricite constatee conducteur'],
#        ["[Nouvel article ] Les travaux de renouvellement d'appareils de voie entre Le Vésinet-Centre et Rueil-Malmaison du 8 au 12 mai approchent à grands pas. Retrouvez plus d'informations sur les substitutions et bien plus encore dans le dernier billet du blog du #RERA \nVoir plus",
#         'nouvel article travaux renouvellement appareils voie mai approchent grands retrouvez plus informations substitutions bien plus encore dernier billet blog voir plus'],
#        ["[#Tchat ] Le #RERA est désormais doté d'un CCU (Centre de Commandement Unique) flambant neuf ! Posez d'ores et déjà vos questions sur cette nouveauté, nous y répondrons en direct le 26 avril à partir de 12:15 lors d'un tchat. https://rera-leblog.fr/tchat-inauguration-du-nouveau-ccu/…",
#         'tchat desormais dote ccu centre commandement unique flambant neuf posez ores deja questions cette nouveaute repondrons direct avril partir lors tchat https leblog fr tchat inauguration nouveau ccu'],
#        ["[#Travaux]  Dans le cadre d'opérations d'entretien des voies, le trafic du #RERA est interrompu jusqu'au 26 avril, tous les soirs du lundi au vendredi à partir de 22h00, entre Cergy–Le Haut • Poissy et Nanterre–Préfecture. Des bus de remplacement sont mis en place\nVoir plus",
#         'travaux cadre operations entretien voies jusqu avril tous soirs lundi vendredi partir bus remplacement mis place voir plus'],
#        ["[#JeudiPhoto ] Retour vers le passé  ! Sauriez-vous deviner l'année de la prise de cette photo en gare de Nanterre-Ville\u202f? #RERA",
#         'jeudiphoto retour passe sauriez deviner annee prise cette photo'],
#        ["[Retour sur incident ] Que s'est-il passé sur votre ligne ce matin ? Nous vous expliquons tout cela ici sur le blog du #RERA ",
#         'retour incident passe matin expliquons tout ici blog'],
#        ["[#MardiConseil] Des questions sur l'utilisation des trottinettes en gare et à bord des trains ? Toutes les réponses dans cet article du blog du #RERA ! ",
#         'mardiconseil questions utilisation trottinettes bord toutes reponses cet article blog'],
#        ['[Nouvel article ] Vous cherchez les actualités de votre ligne ? Tout est disponible dans le nouvel article du blog du #RERA ',
#         'nouvel article cherchez actualites tout disponible nouvel article blog'],
#        ['[#VendrediLecture] Profitons de cette fin de semaine pour (re)découvrir un article du blog du #RERA qui pourrait vous éviter quelques mésaventures...',
#         'vendredilecture profitons cette fin semaine re decouvrir article blog pourrait eviter quelques mesaventures'],
#        ["[Nouvel article ] Besoin d'un justificatif de retard ? Retrouvez toutes les informations dans le nouvel article du blog du #RERA",
#         'nouvel article besoin justificatif retard retrouvez toutes informations nouvel article blog'],
#        ["[JEU CONCOURS] C'est le sprint final pour participer au jeu concours et tenter de remporter 10 places pour le ADIDAS 10K PARIS 2024 du 26 mai ! À vos marques...",
#         'jeu concours sprint final participer jeu concours tenter remporter places adidas k mai marques']],
#       dtype=object)

# %% [markdown]
# ## Trouver la gare source du problème
# A present on sait d'un tweet : s'il parle d'un incident et la typologie de l'incident mentionné ; l'idéal serait de savoir la localisation de l'origine du problème. Il est évident que les gares les plus empruntées (Chatelet, Auber...) concentreront une grande partie des occurrences.
#
# En début d'analyse, les gares détectées dans le tweet ont été récupérées (en maintenant l'ordre d'apparition), et ce qui est bien à ce moment est que la syntaxe des tweets est récurrentes. Très souvent il y a les mêmes formulations de phrases disant qu'un train est à l'arrêt à une X gare à cause d'un problème Y. Cette récurrence de formulation est assez forte pour pouvoir établir des REGEX pour capturer le nom de la gare en question où le problème est survenu.
#
# Et encore une fois, de facon itérative en prenant les tweets d'incidents sur lesquels la gare d'origine de l'incident n'a pas été capturé, on peut ajouter des REGEX.

# %%
df_f.groupby(['label', 'nb_gare_detected']).size()
# Out:
# label                 nb_gare_detected
#                       1                   442
#                       2                   500
#                       3                   340
#                       4                   137
#                       5                    52
#                                          ...
# voyageur              3                    29
#                       4                     9
#                       5                     4
# voyageur,panne train  2                     1
# voyageur,voyageur     2                     1
# Length: 84, dtype: int64

# %%
df_f[(df_f['tweet_type']=="Normal") & (df_f['len_label']>0)]['content'].values
# Out:
# array([" Le trafic est perturbé de Poissy vers Nanterre - Préfecture , en raison d'un incident d'exploitation à Poissy #RERA",
#        " Le train stationne à Gare de Lyon en direction de Cergy–Le Haut en raison de l'actionnement d'un signal d'alarme. #RERA",
#        "Le trafic est perturbé de Boissy-saint-Léger vers la Varennes-Chennevières, en raison d'un incident d'exploitation à Boissy-Saint-Léger. #RERA",
#        "Le train actuellement à Auber et en direction de Boissy-Saint-Léger stationne en raison de l'intervention des agents. #RERA",
#        "Le train actuellement à Val de Fontenay et en direction de Marne-la-Vallée–Chessy stationne en raison de l'intervention des agents. #RERA",
#        " Les trains ne marquent pas l'arrêt en gare de Nanterre\u2006–\u2006Préfecture en direction de Saint-Germain-en-Laye (bagage oublié). #RERA",
#        " Le trafic est perturbé de La Défense vers Cergy-Le Haut • Poissy et Saint-Germain-en-Laye en raison d'un bagage oublié sur le quai à Nanterre\u2006–\u2006Préfecture. #RERA",
#        "Le train actuellement à Nanterre\u2006–\u2006Préfecture et en direction de Poissy stationne en raison d'un incident nécessitant l'intervention des agents. #RERA",
#        "Le train actuellement à La Varenne–Chennevières et en direction de Boissy-Saint-Léger stationne en raison d'un incident nécessitant l'intervention des agents. #RERA",
#        'Le train actuellement à Cergy-Préfecture et en direction de Boissy-Saint-Léger stationne en raison de personnes sur les voies. #RERA',
#        "Le train actuellement au Parc Saint - Maur et en direction de La Défense stationne en raison d'un malaise voyageur. #RERA",
#        "Le train actuellement à Boissy-Saint-Léger et en direction de Cergy-Le Haut stationne en raison d'un incident nécessitant l'intervention des agents. #RERA",
#        "Le train actuellement à Gare de Lyon et en direction de Boissy-Saint-Léger stationne en raison d'un bagage oublié dans un train. #RERA",
#        "Le train actuellement à Torcy et en direction de Marne-la-Vallée–Chessy stationne en raison de l'intervention du conducteur. #RERA",
#        "Le train actuellement à Châtelet–Les Halles et en direction de Saint-Germain-en-Laye stationne en raison d'une personne sur les voies. #RERA",
#        "Le train actuellement à Gare de Lyon et en direction de La Défense stationne en raison de l'actionnement d'un signal d'alarme. #RERA",
#        "Le train actuellement à Houilles–Carrières-sur-Seine et en direction de Poissy stationne en raison de l'actionnement d'un signal d'alarme. #RERA",
#        "Le train actuellement à Nation et en direction de Boissy-Saint-Léger stationne en raison d'un bagage oublié sur le quai à Vincennes. #RERA",
#        "Le train actuellement à Vincennes et en direction de Saint-Germain-en-Laye stationne en raison d'un incident nécessitant l'intervention des agents. #RERA",
#        "Le train actuellement à La Varenne–Chennevières et en direction de Boissy-Saint-Léger stationne en raison d'un incident technique. #RERA",
#        "Le train actuellement à La Varenne–Chennevières et en direction de Boissy-Saint-Léger stationne en raison d'un incident technique à Sucy – Bonneuil. #RERA",
#        "Le train actuellement à Sucy – Bonneuil et en direction de Boissy-Saint-Léger stationne en raison d'un incident technique. #RERA",
#        " Les trains ne marquent pas l'arrêt en gare de La Varenne–Chennevières (inondations). #RERA",
#        "Le train actuellement entre Sucy – Bonneuil et La Varenne–Chennevières et en direction de Poissy stationne en raison de la chute d'un arbre sur les voies. #RERA",
#        "Le train actuellement à Neuville-Université et en direction de Boissy-Saint-Léger stationne en raison d'une altercation entre voyageurs. #RERA",
#        "Le train actuellement à Maisons-Laffitte et en direction de Cergy–Le Haut stationne en raison d'un incident affectant la voie. #RERA",
#        "Les train actuellement entre Fontenay-sous-Bois et Joinville-le-Pont stationnent en raison de la présence d'une personne sur les voies. #RERA",
#        "Le train actuellement à Boissy-Saint-Léger et en direction de Cergy–Le Haut stationne en raison d'un incident technique. #RERA",
#        "Les trains stationnent entre La Défense et Vincennes, en raison d'un incident nécessitant l'intervention de nos agents à Gare de Lyon. #RERA",
#        "Le train actuellement à Rueil-Malmaison et en direction de Saint-Germain-en-Laye stationne en raison de l'intervention des agents. #RERA",
#        "Le train actuellement à La Varenne–Chennevières et en direction de Cergy-Le Haut stationne en raison de l'intervention des agents. #RERA",
#        "Le train actuellement à Noisiel et en direction de Saint-Germain-en-Laye stationne en raison d'une gêne à la fermeture des portes. #RERA",
#        "Le train actuellement à Maisons-Laffitte et en direction de Boissy-Saint-Léger stationne en raison d'un incident nécessitant l'intervention des agents. #RERA",
#
ationne en raison d'une gêne à la fermeture des portes. #RERA",
#        "Le train actuellement à Torcy et en direction de Saint-Germain-en-Laye stationne en raison de l'intervention des agents. #RERA",
#        " Le trafic est perturbé entre Cergy-Le Haut • Poissy et Boissy-Saint-Léger en raison d'un incident d'exploitation à Boissy-Saint-Léger. #RERA",
#        'Le trafic est perturbé de MLV-Chessy vers St-Germain-en-Laye sur le #RERA en raison de personnes sur les voies à Marne-la-Vallée-Chessy.',
#        " L'incident lié au train en panne à Torcy  est terminé. Le trafic est rétabli de Torcy vers Saint-Germain-en-Laye #RERA",
#        "Le train actuellement à Torcy et en direction de Saint-Germain-en-Laye stationne en raison d'un train en panne. #RERA",
#        "Le train actuellement à La Défense et en direction de Marne-la-Vallée–Chessy stationne en raison d'un incident nécessitant l'intervention des agents. #RERA",
#        "Le train actuellement à Rueil-Malmaison et en direction de Marne-la-Vallée–Chessy stationne en raison d'un incident nécessitant l'intervention des agents. #RERA",
#        "Le train actuellement à Nation et en direction de Cergy-Le Haut stationne en raison de l'actionnement d'un signal d'alarme. #RERA",
#        "Le train actuellement à Auber et en direction de Marne-la-Vallée–Chessy stationne en raison de l'actionnement d'un signal d'alarme. #RERA",
#        "Le train actuellement à Vincennes et en direction de Saint-Germain-en-Laye stationne en raison de l'actionnement d'un signal d'alarme. #RERA",
#        " Le trafic est perturbé de Vincennes vers Cergy-Le Haut • Poissy et Saint-Germain-en-Laye en raison d'un train en panne à Auber. #RERA",
#        "Le trafic est perturbé de Maisons-Laffitte vers Poissy sur le #RERA en répercussion d'un incident de signalisation à Poissy.",
#        "Le trafic est perturbé de Maisons-Laffitte vers Poissy sur le #RERA en répercussion d'une panne de signalisation à Poissy.",
#        "Le trafic est perturbé de Poissy vers Marne la Vallée Chessy sur le #RERA en raison d'un incident de signalisation à Poissy.",
#        "Le trafic est perturbé de Boissy St-Léger vers St-Germain En Laye , en raison d'un incident affectant la voie à Boissy St-Léger. #RERA",
#        " Un train stationne à Nation en direction de Saint-Germain-en-Laye, Cergy – Le Haut et Poissy en raison d'un incident affectant la voie. #RERA",
#        " Le trafic est très perturbé de Cergy-Le Haut / Poissy vers Nanterre-Préfecture en raison de difficultés d'exploitation à Cergy-Le Haut et Poissy. #RERA",
#        " Le trafic est perturbé deTorcy vers Cergy-Le Haut en raison d'un incident voyageur à Torcy. #RERA",
#        "Un train stationne à Vincennes en direction de Poissy, en raison de l'actionnement d'un signal d'alarme  #RERA",
#        " Le trafic est perturbé de Nanterre-P vers MLV-Chessy et Boissy-Saint-Léger en raison d'une gêne à la fermeture des portes à La Défense. #RERA",
#        " Le trafic est perturbé de Torcy vers Cergy-Le Haut et Poissy en raison d'un incident technique à Torcy . #RERA",
#        "Le train actuellement à Vincennes et en direction de Marne-la-Vallée–Chessy stationne en raison d'un malaise voyageur. #RERA",
#        " Le trafic est perturbé sur l'ensemble de la ligne en raison d'une panne de signalisation à Gare de Lyon. #RERA",
#        "Le train actuellement à Gare de Lyon et en direction de Boissy-Saint-Léger stationne en raison de l'intervention des équipes techniques. #RERA",
#        "Le train actuellement à Gare de Lyon et en direction de Marne-la-Vallée–Chessy stationne en raison de l'intervention des équipes techniques. #RERA",
#        "Le train actuellement à Auber et en direction de Marne-la-Vallée–Chessy stationne en raison de l'actionnement d'un signal d'alarme. #RERA"],
#       dtype=object)

# %%
gare_source_regex = [
    "stationne à (.*)en raison", 
    "actuellement à (.*) en raison", 
    "ne marquent pas l arret en gare de (.*)",
    "stationne a .* en raison",
    "stationne au .* en raison",
    "stationnement .*? a .* en raison",
    "actuellement .* en raison",
    "en raison .*? a .{10,}",
    "en raison .*? gare .*",
    "est perturbe de (.*)",
    "est perturbe a .* en raison",
    "intervention .*? a .*",
    "en repercussion .*? a .*",
    "stationne .*? a .*",
    "gare .*? en repercussion .*? sur le quai",
    "cela fait suite .*? a .*",
    "panne a .*",
    ]

df_f['gare_source'] = ""
for index, row in df_f.iterrows():
    if row['tweet_type']=='Normal':
        for regex in gare_source_regex:
            match = re.search(regex, row['content_cleaned'])
            if match:
                
                current_text = match.group(0)
                cursor_deb = 0
                cursor_end = 1

                gare_detected = []

                while cursor_end < len(current_text):

                    gare, gare_key = find_gare(current_text[cursor_deb:cursor_end])

                    if gare is None:
                        cursor_end += 1
                    else:
                        gare, cursor_end = find_max_len_gare_from_key(gare_key, gare, current_text, cursor_deb, cursor_end)
                        gare_detected.append(gare_key)
                        cursor_deb = cursor_end
                        cursor_end = cursor_deb + 1 

                print(current_text)
                df_f.loc[index, 'gare_source'] = gare_detected[0]
                break
            elif row['nb_gare_detected']==1:
                df_f.loc[index, 'gare_source'] = row['gare_detected']
                break
# Out:
# en raison d un incident d exploitation a poissy rera
# stationne a gare de lyon en direction de cergy le haut en raison
# en raison d un incident d exploitation a boissy saint leger rera
# actuellement a auber et en direction de boissy saint leger stationne en raison
# actuellement a val de fontenay et en direction de marne la vallee chessy stationne en raison
# ne marquent pas l arret en gare de nanterre prefecture en direction de saint germain en laye bagage oublie rera
# en raison d un bagage oublie sur le quai a nanterre prefecture rera
# actuellement a nanterre prefecture et en direction de poissy stationne en raison
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# actuellement a cergy prefecture et en direction de boissy saint leger stationne en raison
# actuellement au parc saint maur et en direction de la defense stationne en raison
# actuellement a boissy saint leger et en direction de cergy le haut stationne en raison
# actuellement a gare de lyon et en direction de boissy saint leger stationne en raison
# actuellement a torcy et en direction de marne la vallee chessy stationne en raison
# actuellement a chatelet les halles et en direction de saint germain en laye stationne en raison
# actuellement a gare de lyon et en direction de la defense stationne en raison
# actuellement a houilles carrieres sur seine et en direction de poissy stationne en raison
# actuellement a nation et en direction de boissy saint leger stationne en raison
# actuellement a vincennes et en direction de saint germain en laye stationne en raison
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# actuellement a sucy bonneuil et en direction de boissy saint leger stationne en raison
# actuellement entre sucy bonneuil et la varenne chennevieres et en direction de poissy stationne en raison
# actuellement a neuville universite et en direction de boissy saint leger stationne en raison
# actuellement a maisons laffitte et en direction de cergy le haut stationne en raison
# actuellement entre fontenay sous bois et joinville le pont stationnent en raison
# actuellement a boissy saint leger et en direction de cergy le haut stationne en raison
# en raison d un incident necessitant l intervention de nos agents a gare de lyon rera
# actuellement a rueil malmaison et en direction de saint germain en laye stationne en raison
# actuellement a la varenne chennevieres et en direction de cergy le haut stationne en raison
# actuellement a noisiel et en direction de saint germain en laye stationne en raison
# actuellement a maisons laffitte et en direction de boissy saint leger stationne en raison
# actuellement a houilles et en direction de boissy saint leger stationne en raison
# en raison d un incident affectant les voies a vincennes rera
# actuellement a vincennes et en direction de boissy saint leger stationne en raison
# actuellement a vincennes et en direction de marne la vallee chessy stationne en raison
# actuellement a nanterre prefecture et en direction de cergy le haut stationne en raison
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# actuellement a rueil malmaison et en direction de saint germain en laye stationne en raison
# actuellement entre vincennes et val de fontenay et en direction de marne la vallee chessy stationne en raison
# stationnement est prolonge a vincennes en direction de marne la vallee chessy et a neuilly plaisance en direction de cergy le haut en raison
# en raison d un bagage oublie a nanterre prefecture rera
# en raison d un malaise voyageur a maisons laffitte rera
# actuellement a val d europe et en direction de marne la vallee chessy stationne en raison
# en raison d une panne de signalisation a acheres ville rera
# actuellement a la defense et en direction de marne la vallee chessy stationne en raison
# en raison d un bagage oublie sur un quai a val de fontenay reprise estimee a rera
# stationne a vincennes en direction de saint germain en laye en raison
# en raison d une panne de signalisation a houilles carrieres sur seine rera
# en raison d un train en panne a maisons laffitte rera
# en raison d une gene a la fermeture des portes d un train a la defense rera
# stationne a bussy saint georges en direction de poissy en raison
# actuellement a val d europe et en direction de saint germain en laye stationne en raison
# actuellement a auber et en direction de boissy saint leger stationne en raison
# en raison d un bagage oublie a nanterre ville rera
# actuellement a nanterre ville et en direction saint germain en laye stationne en raison
# actuellement a chatelet les halles et en direction de cergy le haut stationne en raison
# actuellement a noisy champs et en direction de saint germain en laye stationne en raison
# actuellement a sucy bonneuil et en direction de boissy saint leger stationne en raison
# actuellement a gare de lyon et en direction de marne la vallee chessy stationne en raison
# actuellement a val d europe et en direction de marne la vallee chessy stationne en raison
# actuellement a val d europe et en direction de marne la vallee chessy stationne en raison
# en raison d un incident d exploitation a nanterre prefecture rera
# actuellement a la defense et en direction de poissy stationne en raison
# actuellement a chatelet les halles et en direction de boissy saint leger stationne en raison
# actuellement a rueil malmaison et en direction de saint germain en laye stationne en raison
# actuellement a chatelet les halles et en direction de poissy stationne en raison
# stationnement est prolonge a noisy champs en direction de marne la vallee chessy en raison
# en raison d un incident voyageur a nation rera
# actuellement a auber et en direction de poissy stationne en raison
# actuellement a saint maur creteil et en direction de boissy saint leger stationne en raison
# actuellement a gare de lyon et en direction de saint germain en laye stationne en raison
# actuellement entre champigny et sucy bonneuil stationnent en raison
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# actuellement a torcy et en direction de marne la vallee chessy stationne en raison
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# actuellement a torcy et en direction de saint germain en laye stationne en raison
# actuellement a chatelet les halles et en direction de poissy stationne en raison
# actuellement entre torcy et marne la vallee chessy stationnent en raison
# actuellement a la varenne chennevieres et en direction de poissy stationne en raison
# en raison d une panne de portes de train a val de fontenay rera
# en raison d une panne de train a cergy le haut rera
# actuellement a chatelet les halles et en direction de marne la vallee chessy stationne en raison
# en raison d une panne de signalisation a acheres ville rera
# en raison d un malaise voyageur a poissy rera
# en raison d un malaise voyageur a acheres ville rera
# actuellement a rueil malmaison et en direction de marne la vallee chessy stationne en raison
# actuellement a chatelet les halles et en direction de marne la vallee chessy stationne en raison
# actuellement a noisy le grand mont d est et en direction de marne la vallee chessy stationne en raison
# actuellement entre auber et vincennes dans les deux sens de circulation stationnent en raison
# actuellement a gare de lyon et en direction de poissy stationne en raison
# actuellement a sartrouville et en direction de cergy le haut stationne en raison
# en raison d un incident d exploitation a cergy le haut rera
# en raison d un malaise voyageur a charles de gaulle etoile rera
# actuellement a marne la vallee chessy et en direction de saint germain en laye stationne en raison
# actuellement a noisy le grand mont d est et en direction de saint germain en laye stationne en raison
# actuellement a acheres ville et en direction de boissy saint leger stationne en raison
# actuellement a gare de lyon et en direction de boissy saint leger stationne en raison
# stationnement est prolonge a torcy en direction de poissy en raison
# stationnement est prolonge a la defense en direction de marne la vallee chessy en raison
# en raison d un incident voyageur a chatelet les halles
# est perturbe de cergy le haut vers marne la vallee sur le rera en repercussion d un malaise voyageur a cergy saint christophe
# stationne a poissy en direction de marne la vallee chessy sur le rera en raison
# stationne a nanterre prefecture en direction de boissy saint leger sur le rera en raison
# actuellement a vincennes et en direction de la defense stationne en raison
# en raison d une rupture de catenaire a acheres ville reprise estimee a rera
# actuellement a bussy saint georges et en direction de marne la vallee chessy stationne en raison
# actuellement a val de fontenay et en direction de marne la vallee chessy stationne en raison
# actuellement a lognes et en direction de marne la vallee chessy stationne en raison
# actuellement a nanterre prefecture et en direction de saint germain en laye stationne en raison
# actuellement a cergy saint christophe et en direction de boissy saint leger stationne en raison
# actuellement a la defense et en direction de saint germain en laye stationne en raison
# actuellement a noisy le grand mont d est et en direction de marne la vallee chessy stationne en raison
# en raison d un train en panne a conflans fin doise rera
# en raison d une panne de portes de train a rueil malmaison rera
# en raison d un train en panne a saint germain en laye rera
# actuellement a nation et en direction de saint germain en laye stationne en raison
# actuellement entre bussy saint georges et val d europe en direction de marne la vallee chessy stationnent en raison
# en raison d un rallongement de duree de chantier a boissy saint leger rera
# en raison d un malaise voyageur a nation rera
# en raison d un incident voyageur a marne la vallee chessy rera
# en raison d une panne de signalisation a poissy rera
# stationne a le parc de saint maur en direction de cergy le haut en raison
# actuellement a neuilly plaisance et en direction de saint germain en laye stationne en raison
# actuellement a la defense et en direction de cergy le haut stationne en raison
# actuellement a chatelet les halles et en direction de poissy stationne en raison
# actuellement a la defense et en direction du vesinet le pecq stationne en raison
# en raison d une altercation entre voyageurs a vincennes rera
# en raison d un malaise voyageur a marne la vallee chessy rera
# actuellement a conflans fin doise et en direction de boissy saint leger stationne en raison
# actuellement a gare de lyon et en direction de boissy saint leger stationne en raison
# actuellement a nation et en direction de marne la vallee chessy stationne en raison
# actuellement a nation et en direction de saint germain en laye stationne en raison
# en raison d une altercation entre voyageurs a nanterre universite rera
# actuellement a noisy le grand mont d est et en direction de saint germain en laye stationne en raison
# actuellement a bry sur marne et en direction de marne la vallee chessy stationne en raison
# actuellement a sartrouville et en direction de boissy saint leger stationne en raison
# actuellement a acheres ville et en direction de boissy saint leger stationne en raison
# gare de bry sur marne n est pas desservie en direction de marne la vallee en repercussion d un incident technique sur le quai
# en raison d un bagage oublie sur un quai a nanterre prefecture rera
# en raison de l actionnement d un signal d alarme a chatelet les halles rera
# stationnement est prolonge a chatelet les halles en direction de boissy saint leger en raison
# stationne a neuville universite en direction de cergy le haut en raison
# en raison d un train en panne a acheres ville rera
# est perturbe de marne la vallee chessy vers saint germain en laye en repercussion d un bagage oublie sur un quai a bussy saint georges rer_a
# stationne a chatelet les halles en direction de boissy saint leger et marne la vallee chessy en raison
# actuellement a nanterre prefecture et en direction de poissy stationne en raison
# actuellement entre torcy et bussy saint georges et en direction de marne la vallee chessy saint germain en laye stationnent en raison
# stationnement est prolonge a joinville le pont en direction de poissy en raison
# actuellement a vincennes et en direction de poissy stationne en raison
# en raison d une panne de signalisation a houilles carrieres sur seine rera
# actuellement a la defense et en direction de boissy saint leger stationne en raison
# en raison d un incident affectant les voies a acheres ville rera
# stationne au vesinet le pecq en direction de saint germain en laye en raison
# en raison de la panne d un train a conflans fin doise rera
# en raison d un train en panne a cergy le haut rera
# en raison d un incident d exploitation a marne la vallee chessy rera
# actuellement a bry sur marne et en direction de marne la vallee chessy stationne en raison
# actuellement a val d europe et en direction de marne la vallee chessy stationne en raison
# est perturbe de poissy vers nanterre prefecture gene a la fermeture des portes d un train rera
# en raison d un train en panne a poissy rera
# actuellement a neuilly plaisance et en direction de saint germain en laye stationne en raison
# actuellement a nanterre universite et en direction de marne la vallee chessy stationne en raison
# actuellement a torcy et en direction de marne la vallee chessy stationne en raison
# en raison d un train en panne a nanterre prefecture rera
# en raison d un train en panne a poissy rera
# intervention des equipes techniques a bussy saint georges nous vous invitons a emprunter des itineraires alternatifs rera
# stationne a bussy saint georges en direction de cergy le haut en raison
# en raison d une degradation volontaire a torcy rera
# stationne a charles de gaulle etoile en direction de marne la vallee chessy en raison
# stationne a auber en direction de saint germain en laye en raison
# en raison de personnes sur les voies a neuilly plaisance rera
# actuellement a gare de lyon et en direction de boissy saint leger stationne en raison
# actuellement a fontenay sous bois et en direction de boissy saint leger stationne en raison
# en raison d un bagage oublie dans un train a boissy saint leger rera
# en raison d un incident d exploitation a marne la vallee chessy rera
# actuellement a val de fontenay et en direction de marne la vallee chessy stationne en raison
# actuellement a gare de lyon et en direction de marne la vallee chessy stationne en raison
# actuellement a charles de gaulle etoile et en direction de boissy saint leger stationne en raison
# actuellement a nation et en direction de cergy le haut stationne en raison
# en raison d un train en panne a cergy saint christophe rera
# en raison d un rallongement de duree de chantier a boissy saint leger ratp
# stationnement est prolonge a fontenay sous bois en direction de saint germain en laye en raison
# actuellement a noisiel et en direction de marne la vallee chessy stationne en raison
# actuellement a charles de gaulle etoile et en direction de boissy saint leger stationne en raison
# actuellement a la defense et en direction de cergy le haut stationne en raison
# actuellement a val d europe et en direction de marne la vallee chessy stationne en raison
# en raison d un incident d exploitation a maisons laffitte rera
# en raison d un bagage oublie dans un train a marne la vallee chessy rera
# en raison d un train en panne a nogent sur marne rera
# actuellement a gare de lyon et en direction du vesinet le pecq stationne en raison
# actuellement a sartrouville et en direction de boissy saint leger stationne en raison
# actuellement a lognes et en direction de marne la vallee chessy stationne en raison
# actuellement a rueil malmaison et en direction de saint germain en laye stationne en raison
# en raison d un incident technique sur un train a marne la vallee chessy rera
# en raison d une altercation entre voyageurs a gare de lyon rera
# en raison d une altercation entre voyageurs a gare de lyon rera
# actuellement a chatelet les halles et en direction de marne la vallee chessy stationne en raison
# en raison d un bagage oublie a poissy rera
# actuellement a gare de lyon et en direction de marne la vallee chessy stationne en raison
# en raison d un incident d exploitation a acheres ville rera
# actuellement a auber et en direction de cergy le haut stationne en raison
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# actuellement a nogent sur marne et en direction de boissy saint leger stationne en raison
# en raison de l actionnement d un signal d alarme a auber rera
# en raison d une panne electrique a sucy bonneuil rera
# stationne pour une dizaine de minutes a bussy saint georges en direction de marne la vallee chessy en raison d une intervention des equipes techniques rera
# est perturbe de boissy saint leger vers la defense en raison d un incident d exploitation rera
# stationnement est prolonge a gare de lyon en direction de saint germain en laye en raison
# actuellement a lognes et en direction de marne la vallee chessy stationne en raison
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# en raison d une panne de signalisation a houilles carrieres sur seine rera
# actuellement a val de fontenay et en direction de torcy stationne en raison
# en raison d un incident affcetant la voie a sartrouville rera
# en raison d un bagage oublie sur le quai a cergy prefecture et est perturbe sur le reste de la ligne reprise estimee a rera
# actuellement a val de fontenay et en direction de marne la vallee chessy stationne en raison
# en raison d une panne de portes de train a sucy bonneuil rera
# actuellement a sucy bonneuil et en direction de cergy le haut stationne en raison
# actuellement au vesinet le pecq et en direction de saint germain en laye stationne en raison
# actuellement a joinville le pont et en direction de cergy le haut stationne en raison
# actuellement a auber et en direction de cergy le haut stationne en raison
# actuellement a chatelet les halles et en direction de saint germain en laye stationne en raison
# en raison d un incident d exploitation a gare de lyon rera
# en raison d une panne de signalisation a neuilly plaisance rera
# actuellement a val d europe et en direction de marne la vallee chessy stationne en raison
# actuellement a torcy et en direction de saint germain en laye stationne en raison
# actuellement entre bussy saint georges et marne la vallee chessy et en direction de marne la vallee chessy stationnent en raison
# en raison d un incident affectant la voie a sartrouville rera
# actuellement a chatelet les halles et en direction de marne la vallee chessy stationne en raison
# actuellement a gare de lyon et en direction de saint germain en laye stationne en raison
# actuellement a charles de gaulle etoile et en direction de rueil malmaison stationne en raison
# actuellement a torcy et en direction de marne la vallee chessy stationne en raison
# actuellement a auber et en direction de torcy stationne en raison
# est perturbe de marne la vallee chessy vers poissy en repercussion d un rallongement de duree de chantier a torcy rera
# en raison d un train en panne a boissy saint leger rera
# actuellement entre vincennes et fontenay sous bois en direction de boissy saint leger stationne en raison
# actuellement a val d europe et en direction de marne la vallee chessy stationne en raison
# actuellement a marne la vallee chessy et en direction de marne la vallee chessy stationne en raison
# actuellement a nanterre ville et en direction de marne la vallee chessy stationne en raison
# actuellement a la defense et en direction de boissy saint leger stationne en raison
# en raison d une panne de train a sucy bonneuil rera
# actuellement a la defense et en direction de marne la vallee chessy stationne en raison
# stationne a saint germain en laye en direction de boissy saint leger en raison
# cela fait suite a un accident grave de personne a nation rera
# en raison d un incident d exploitation a boissy saint leger rera
# actuellement a neuilly plaisance et en direction de rueil malmaison stationne en raison
# actuellement a bry sur marne et en direction de marne la vallee chessy stationne en raison
# actuellement a acheres ville et en direction de cergy le haut stationne en raison
# actuellement a lognes et en direction du le vesinet le pecq stationne en raison
# stationne a la defense en direction de saint germain en laye en raison
# en raison d un incident d exploitation a la defense rera
# en raison de personnes sur les voies a cergy saint christophe rera
# est perturbe de nanterre prefecture vers cergy le haut en raison d un incident d exploitation rera
# actuellement a joinville le pont et en direction de cergy le haut stationne en raison
# actuellement a chatelet les halles et en direction de saint germain en laye stationne en raison
# actuellement a rueil malmaison et en direction de saint germain en laye stationne en raison
# actuellement a nanterre prefecture et en direction de marne la vallee chessy stationne en raison
# actuellement a bussy saint georges et en direction de saint germain en laye stationne en raison
# ne marquent pas l arret en gare de houilles carrieres sur seine en direction de boissy saint leger et torcy bagage oublie sur le quai rera
# actuellement a la defense et en direction de boissy saint leger stationne en raison
# stationnement est prolonge a marne la vallee chessy en direction de saint germain en laye en raison
# en raison d un train en panne a chatelet les halles rera
# en raison d un train en panne a maison laffitte rera
# en raison d une panne de signalisation a torcy rera
# actuellement a vincennes et en direction de boissy saint leger stationne en raison
# actuellement a torcy et noisy champs et en direction de marne la vallee chessy et poissy cergy le haut stationnent en raison
# en raison d un incident affectant la voie a acheres grand cormier rera
# en raison de la panne d un train a poissy rera
# en raison d un incident d exploitation a boissy saint leger rera
# en raison d un incident affectant les voies a cergy saint christophe rera
# actuellement a nanterre ville et en direction de saint germain en laye stationne en raison
# actuellement a boissy saint leger et en direction de cergy le haut stationne en raison
# en raison d une difficultes d exploitation a poissy rera
# actuellement a torcy et en direction de marne la vallee chessy stationne en raison
# actuellement a nanterre prefecture et en direction de poissy stationne en raison
# cela fait suite a un incident affectant les voies a bussy saint georges rera
# actuellement a chatelet les halles et en direction de marne la vallee chessy stationne en raison
# actuellement a bry sur marne et en direction du vesinet le pecq stationne en raison
# actuellement entre bussy saint georges et torcy et en direction de saint germain en laye stationne en raison
# actuellement a rueil malmaison et en direction de marne la vallee chessy stationne en raison
# actuellement a champigny et en direction de poissy stationne en raison
# actuellement a nanterre prefecture et en direction de poissy stationne en raison
# actuellement a chatelet les halles et en direction de torcy stationne en raison
# en raison d un incident d exploitation a la defense rera
# en raison d une panne d une portes de train a nanterre prefecture rera
# actuellement a auber et en direction de marne la vallee chessy stationne en raison
# actuellement a saint germain en laye et en direction de marne la vallee chessy stationne en raison
# actuellement a la varenne chennevieres et en direction de cergy le haut stationne en raison
# actuellement a torcy et en direction de saint germain en laye stationne en raison
# actuellement a chatelet les halles et en direction de marne la vallee chessy stationne en raison
# actuellement a chatelet les halles et en direction de saint germain en laye stationne en raison
# actuellement a noisy le grand mont d est et en direction de marne la vallee chessy stationne en raison
# actuellement a sucy bonneuil et en direction de cergy le haut stationne en raison
# actuellement a val de fontenay et en direction de rueil malmaison stationne en raison
# en raison d un incident d exploitation a torcy rera
# en raison d un train en panne a cergy le haut rera
# est perturbe de cergy le haut vers nanterre prefecture rera
# en raison d une degradation volontaire a noisy le grand mont d est rera
# en raison d un incident d exploitation a poissy heure de reprise estimee rera
# actuellement a nation et en direction de boissy saint leger stationne en raison
# en raison d un bagage oublie a saint germain en laye rera
# en raison de la panne d un train a nanterre prefecture rera
# en raison d un incident d exploitation a boissy saint leger rera
# en raison de l intervention des forces de l ordre a sartrouville rera
# actuellement a torcy et en direction de marne la vallee chessy stationne en raison
# actuellement a val d europe et en direction de marne la vallee chessy stationne en raison
# actuellement a la defense et en direction de saint germain en laye stationne en raison
# en raison d un bagage oublie dans un train a marne la vallee chessy rera
# en raison d un incident affectant la voie a nation reprise estimee a rera
# en raison d un incident affectant la voie a nation rera
# en raison d une panne de train a neuville universite rera
# actuellement a vincennes et en direction de marne la vallee chessy stationne en raison
# actuellement a chatelet les halles et en direction de la defense stationne en raison
# en raison d un incident affectant la voie a acheres ville rera
# actuellement a gare de lyon et en direction de poissy stationne en raison
# actuellement a gare de lyon et en direction de cergy le haut stationne en raison
# en raison d une panne de train a sartrouville rera
# en repercussion d un train en panne a val de fontenay l heure de reprise estimee est h rera
# en raison d un incident voyageur a vincennes rera
# en raison d un malaise voyageur a maisons laffitte rera
# actuellement a boissy saint leger et en direction de cergy le haut stationne en raison
# actuellement a nanterre ville et en direction de rueil malmaison stationne en raison
# actuellement a val de fontenay et en direction de marne la vallee chessy stationne en raison
# actuellement a torcy et en direction de marne la vallee chessy stationne en raison
# actuellement a charles de gaulle etoile et en direction de marne la vallee chessy stationne en raison
# actuellement a val d europe et en direction de marne la vallee chessy stationne en raison
# actuellement a nanter
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# en raison d un train en panne a bry sur marne rera
# actuellement a noisy le grand mont d est et en direction de saint germain en laye stationne en raison
# actuellement a auber et en direction saint germain en laye stationne en raison
# en raison d un train en panne a poissy rera
# en raison d un bagage oublie a cergy le haut rera
# actuellement a nanterre prefecture et en direction de boissy saint leger stationne en raison
# actuellement entre lognes et bussy saint georges et en direction de saint germain en laye et marne la vallee chessy stationnent en raison
# actuellement a torcy et en direction de marne la vallee chessy stationne en raison
# actuellement a nanterre prefecture et en direction de saint germain en laye stationne en raison
# actuellement a auber et en direction de saint germain en laye stationne en raison
# actuellement entre bry sur marne et noisy le grand mont d est et en direction de marne la vallee chessy stationne en raison
# actuellement a marne la vallee chessy et en direction de saint germain en laye stationne en raison
# actuellement a val d europe et en direction de marne la vallee chessy stationne en raison
# actuellement a boissy saint leger et en direction de boissy saint leger stationne en raison
# en raison d un train en panne a acheres ville rera
# actuellement a auber et en direction de cergy le haut stationne en raison
# en raison d un train en panne a torcy rera
# actuellement a gare de lyon et en direction de saint germain en laye stationne en raison
# actuellement a la defense et en direction de saint germain en laye stationne en raison
# actuellement a saint germain en laye et en direction de marne la vallee chessy stationne en raison
# actuellement entre la defense et chatelet les halles et en direction de boissy saint leger marne la vallee chessy stationnent en raison
# actuellement a nanterre prefecture et en direction de boissy saint leger stationne en raison
# en raison d une panne de signalisation a gare de lyon rera
# actuellement a chatelet les halles et en direction de torcy stationne en raison
# actuellement a val de fontenay et en direction de saint germain en laye stationne en raison
# en raison d un malaise voyageur a gare de lyon rera
# actuellement a gare de lyon et en direction de vesinet le pecq stationne en raison
# actuellement a vincennes et en direction de saint germain en laye stationne en raison
# en raison de difficultes d exploitation a poissy rera
# est perturbe de poissy vers nanterre prefecture sur le rera en repercussion de difficultes d exploitation a poissy
# en raison d un train en panne a nanterre prefecture rera
# en raison d un train en panne a nanterre prefecture rera
# en raison d un bagage oublie a torcy rera
# en raison d une degradation volontaire a torcy rera
# en raison d un malaise voyageur a nogent sur marne
# en raison d un train en panne a cergy le haut
# en raison d un train en panne a marne la vallee chessy
# actuellement a noisy le grand mont d est et en direction de marne la vallee chessy stationne en raison
# actuellement a charles de gaulle etoile et en direction de cergy le haut stationne en raison
# actuellement a charles de gaulle etoile et en direction de marne la vallee chessy stationne en raison
# actuellement a nanterre prefecture et en direction de cergy le haut stationne en raison
# en repercussion d un train en panne a boissy saint leger le trafic est perturbe poissy saint leger vers poissy rera
# en raison d une panne de signalisation a neuville universite rera
# actuellement a lognes et en direction de saint germain en laye stationne en raison
# en raison d une panne electrique a noisy le grand mont d est rera
# actuellement a torcy et en direction de saint germain en laye stationne en raison
# actuellement a saint germain en laye et en direction de marne la vallee chessy stationne en raison
# actuellement a chatelet les halles et en direction de marne la vallee chessy stationne en raison
# actuellement a chatelet les halles et en direction de marne la vallee chessy stationne en raison
# est perturbe de cergy le haut vers nanterre prefecture en raison de difficultes d exploitation rera
# actuellement a noisiel et en direction de torcy stationne en raison
# actuellement a maisons laffitte et en direction de boissy saint leger stationne en raison
# actuellement a chatelet les halles et en direction de rueil malmaison stationne en raison
# en raison d un train en panne a marne la vallee chessy et tres perturbe de st germain en laye vers rueil malmaison sur le rera en raison d une panne electrique a saint germain en laye
# en raison d un bagage oublie en gare de marne la vallee chessy le trafic est interrompu entre marne la vallee chessy et val d europe la reprise est estimee vers h rera
# actuellement a nanterre prefecture et en direction de cergy le haut poissy stationne en raison
# actuellement a charles de gaulle etoile et en direction de poissy stationne en raison
# actuellement a nanterre prefecture et en direction de marne la vallee chessy stationne en raison
# en raison d un bagage oublie a torcy rera
# actuellement a torcy et en direction de marne la vallee chessy stationne en raison
# actuellement a nanterre ville et en direction de marne la vallee chessy stationne en raison
# actuellement a nation et en direction de marne la vallee chessy stationne en raison
# actuellement a val de fontenay et en direction de saint germain en laye stationne en raison
# en raison d une panne de signalisation a auber rera
# en raison d un malaise voyageur a nanterre universite rera
# en raison d un malaise voyageur a nanterre universite rera
# en raison de difficultes d exploitation a torcy rera
# actuellement a charles de gaulle etoile et en direction de marne la vallee chessy stationne en raison
# actuellement a charles de gaulle etoile et en direction de marne la vallee chessy stationne en raison
# actuellement a torcy et en direction de saint germain en laye stationne en raison
# en raison d un train en panne a cergy prefecture rera
# en raison d un bagage oublie a gare de lyon rera
# en raison de difficultes d exploitation a poissy et de saint germain vers marne la vallee chessy chessy et boissy saint leger en raison d une panne electrique a rueil malmaison rera
# en raison de l actionnement d un signal d alarme a la defense rera
# en raison d un incident affectant la voie a le vesinet le pecq rera
# en raison d un incident affectant la voie a acheres ville rera
# actuellement a noisy le grand mont d est et en direction de saint germain en laye stationne en raison
# actuellement a chatelet les halles et en direction de saint germain en laye stationne en raison
# en raison d un incident d exploitation a torcy rera
# actuellement a sucy bonneuil et en direction de cergy le haut stationne en raison
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# actuellement a torcy et en direction de poissy stationne en raison
# en raison d un degagement de fumee a vincennes rera
# en raison d une panne de signalisation a sucy bonneuil rera
# actuellement a auber et en direction de torcy stationne en raison
# en raison de la panne d un train a marne la vallee chessy rera
# en repercussion d une panne electrique a maisons laffitte rera
# en raison d un incident d exploitation a vincennes rera
# actuellement a noisy le grand mont d est et en direction de torcy stationne en raison
# actuellement a la defense et en direction de rueil malmaison stationne en raison
# actuellement a boissy saint leger et en direction de cergy le haut stationne en raison
# actuellement a rueil malmaison et en direction de saint germain en laye stationne en raison
# actuellement a auber et en direction de saint germain en laye stationne en raison
# actuellement a torcy et en direction de marne la vallee chessy stationne en raison
# actuellement a nation et en direction de torcy stationne en raison
# actuellement a la defense et en direction de rueil malmaison stationne en raison
# est perturbe de cergy prefecture vers torcy en repercussion de l actionnement d un signal d alarme a cergy prefecture rera
# en raison d un incident voyageur a marne la vallee chessy rera
# actuellement a nanterre prefecture et en direction de saint germain en laye stationne en raison
# actuellement a rueil malmaison et en direction de saint germain en laye stationne en raison
# actuellement a nanterre prefecture et en direction de marne la vallee chessy stationne en raison
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# en raison d un incident de signalisation a gare de lyon rera
# en raison de la panne d un train de la ligne l a nanterre universite rera
# en raison d un rallongement de duree de chantier a rueil malmaison rera
# est perturbe de gare de lyon vers st germain en laye poissy et cergy le haut gene a la fermeture des portes rera
# en raison d un incident d exploitation a rueil malmaison rera
# actuellement a nanterre ville et en direction de rueil malmaison stationne en raison
# en raison d une panne de signalisation a nanterre prefecture et d un malaise voyageur a cergy prefecture rera
# actuellement entre houilles carrieres sur seine et nanterre prefecture et en direction de boissy saint leger stationne en raison
# actuellement a auber et en direction de saint germain en laye stationne en raison
# stationnement est prolonge a noisiel en direction de marne la vallee chessy en raison
# stationnement est prolonge a torcy en direction de cergy le haut en raison
# en raison d un animal sur les voies a le vesinet le pecq rera
# en raison d un incident technique a poissy rera
# en raison d une panne de signalisation a acheres ville rera
# stationnement est prolonge a nation en direction de poissy en raison
# stationne a vincennes en direction de boissy saint leger en raison
# en raison d un incident affectant la voie a chatelet les halles rera
# est perturbe de poissy cergy le haut vers nanterre prefecture rera
# en repercussion de difficultes d exploitation en gare de rueil malmaison le trafic est perturbe a rueil malmaison en direction de torcy rera
# actuellement a torcy et en direction de marne la vallee chessy stationne en raison
# actuellement a auber et en direction de boissy saint leger stationne en raison
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# actuellement a nanterre prefecture et en direction de poissy stationne en raison
# actuellement a nanterre prefecture et en direction de cergy le haut stationne en raison
# actuellement a val d europe et en direction de marne la vallee chessy stationne en raison
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# en raison d un incident d exploitation a saint germain en laye rera
# actuellement a torcy et en direction de saint germain en laye stationne en raison
# actuellement a champigny et en direction de la varenne chennevieres stationne en raison
# actuellement a chatelet les halles et en direction de poissy stationne en raison
# actuellement a rueil malmaison et en direction de marne la vallee chessy stationne en raison
# cela fait suite a un bagage oublie a torcy rer_a
# en raison d un malaise voyageur a charles de gaulle etoile rer_a
# stationne a chatelet les halles en direction de boissy saint leger en raison
# en raison d un rallongement de duree de chantier a rueil malmaison rera
# en raison d un rallongement de duree de chantier a rueil malmaison rera
# en raison d un train en panne a cergy saint christophe rera
# en raison d un rallongement de duree de chantier a saint germain en laye rera
# actuellement a nation et en direction de boissy saint leger stationne en raison
# actuellement a nanterre prefecture et en direction de cergy le haut stationne en raison
# actuellement a chatelet les halles et en direction de marne la vallee chessy stationne en raison
# actuellement a bry sur marne et en direction de marne la vallee chessy stationne en raison
# actuellement a bussy saint georges et en direction de marne la vallee chessy stationne en raison
# actuellement a nanterre prefecture et en direction de marne la vallee chessy stationne en raison
# actuellement a nogent sur marne et en direction de poissy stationne en raison
# actuellement a torcy et en direction de marne la vallee chessy stationne en raison
# actuellement a neuilly plaisance et en direction de torcy stationne en raison
# actuellement a bry sur marne et en direction de torcy stationne en raison
# actuellement a la defense et en direction de saint germain en laye stationne en raison
# actuellement a nation et en direction de poissy stationne en raison
# actuellement a neuilly plaisance et en direction de torcy stationne en raison
# actuellement a nanterre prefecture et en direction de boissy saint leger stationne en raison
# actuellement a chatelet les halles et en direction de boissy saint leger stationne en raison
# actuellement a fontenay sous bois et en direction de boissy saint leger stationne en raison
# actuellement a gare de lyon et en direction de cergy le haut stationne en raison
# actuellement a auber et en direction de saint germain en laye stationne en raison
# en raison d une panne electrique a cergy le haut rera
# en raison d une panne de signalisation a maisons laffitte rera
# en raison d un incident d exploitation a mlv chessy rera
# en raison d un incident d exploitation a cergy le haut rera
# actuellement a quai a acheres grand cormier et en direction de poissy stationne en raison
# actuellement entre fontenay sous bois et vincennes stationne en raison
# actuellement entre lognes et torcy stationne en raison
# actuellement a quai a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# actuellement entre val de fontenay et vincennes et en direction de la defense stationne en raison
# en raison de difficultes d exploitation a poissy rera
# en raison d un incident d exploitation a torcy rera
# en raison de difficultes d exploitation a poissy rera
# stationnement est prolonge a noisiel en direction de saint germain en laye en raison
# cela fait suite a un degagement de fumee a bussy saint georges les pompiers sont en cours intervention bus de remplacement mis en place rera
# en raison d un degagement de fumee a bussy saint georges reprise estimee a rera
# actuellement a nanterre prefecture et en direction de cergy le haut stationne en raison
# actuellement a nanterre prefecture et en direction de torcy et boissy saint leger stationnent en raison
# en raison d un degagement de fumee a nanterre ville sur le rera
# en raison d un malaise voyageur a maisons laffitte rera
# en raison d un train en panne a fontenay sous bois sur la ligne rera
# en raison d une altercation entre voyageurs a houilles carrieres sur seine sur la ligne rera
# est perturbe de torcy vers saint germain en laye en repercussion d un incident d exploitation a torcy rera
# en raison de difficultes d exploitation a poissy rera
# en raison d un incident technique a nation rera
# stationne a auber en direction de boissy saint leger en raison
# en raison d un incident affectant la voie a bry sur marne rera
# actuellement a noisy le grand mont d est et en direction de rueil malmaison stationne en raison
# actuellement a maisons laffitte et en direction de cergy le haut stationne en raison
# stationnement est prolonge a chatelet les halles en direction de saint germain en laye cergy le haut et poissy en raison
# en raison de personnes sur les voies a cergy prefecture rera
# est perturbe de vincennes vers boissy saint leger en repercussion de l actionnement d un signal d alarme a fontenay sous bois rera
# en raison d un malaise voyageur a torcy rera
# est perturbe de cergy le haut vers nanterre prefecture en repercussion d un train en panne a cergy le haut jusqu a h rera
# actuellement a nanterre prefecture et en direction de saint germain en laye stationne en raison
# actuellement a nanterre universite et en direction de marne la vallee chessy stationne en raison
# actuellement a la varenne chennevieres et en direction de cergy le haut stationne en raison
# actuellement entre la defense et charles de gaulle etoile et en direction de marne la vallee chessy stationne en raison
# actuellement a noisiel et en direction de marne la vallee chessy stationne en raison
# actuellement a champigny et en direction de poissy stationne en raison
# en raison d une voie occupee par un autre train a acheres ville rera
# actuellement a gare de lyon et en direction de le vesinet le pecq stationne en raison
# actuellement a noisiel et en direction de saint germain en laye stationne en raison
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# actuellement a chatelet les halles et en direction de marne la vallee chessy stationne en raison
# actuellement a nanterre prefecture et en direction de cergy le haut stationne en raison
# en raison d un incident necessitant l intervention de nos agents a boissy saint leger rera
# actuellement a chatelet les halles et en direction de saint germain en laye stationne en raison
# actuellement a rueil malmaison et en direction de saint germain en laye stationne en raison
# actuellement a chatelet les halles et en direction de torcy stationne en raison
# actuellement a neuilly plaisance et en direction de marne la vallee chessy stationne en raison
# actuellement a gare de lyon et en direction de boissy saint leger stationne en raison
# en raison d un rallongement de duree de chantier a val d europe rera
# stationnement est prolonge a torcy en direction de marne la vallee chessy en raison
# stationnement est prolonge a auber en direction de marne la vallee chessy en raison
# actuellement a nanterre prefecture et en direction de poissy stationne en raison
# en raison d un incident voyageur a cergy prefecture rera
# actuellement a nanterre prefecture et en direction de boissy saint leger stationne en raison
# actuellement a la defense et en direction de cergy le haut stationne en raison
# actuellement a rueil malmaison et en direction de marne la vallee chessy stationne en raison
# en raison d un incident affectant la voie a acheres ville rera
# est perturbe a nanterre prefecture en direction de marne la vallee chessy sur le rera en raison
# stationnement est prolonge a nanterre prefecture en direction de poissy sur le rera en raison
# en raison d une panne de signalisation a cergy saint christophe rera
# est perturbe de boissy saint leger vers saint germain en laye en repercussion d un malaise voyageur a sucy bonneuil rera
# en raison de personnes sur les voies a acheres ville rera
# cela fait suite a un rallongement de duree de chantier a bussy st georges rera
# actuellement a gare de lyon et en direction de boissy saint leger stationne en raison
# actuellement a rueil malmaison et en direction de marne la vallee chessy stationne en raison
# actuellement a torcy et en direction de marne la vallee chessy stationne en raison
# actuellement a nanterre prefecture et en direction de marne la vallee chessy stationne en raison
# actuellement a auber et en direction de boissy saint leger stationne en raison
# actuellement a auber et en direction de marne la vallee chessy stationne en raison
# actuellement a nanterre prefecture et en direction de torcy stationne en raison
# actuellement a chatelet les halles et en direction de saint germain en laye stationne en raison
# en raison d une panne de signalisation a auber rera
# actuellement a auber et en direction de marne la vallee chessy stationne en raison
# stationnement est prolonge a auber en direction de saint germain en laye en raison
# en raison d un malaise voyageur a poissy rera
# actuellement a val de fontenay et en direction de marne la vallee chessy stationne en raison
# actuellement a chatelet les halles et en direction de boissy saint leger stationne en raison
# actuellement a la defense et en direction de saint germain en laye stationne en raison
# actuellement a vincennes et en direction de saint germain en laye stationne en raison
# actuellement a la defense et en direction de saint germain en laye et cergy le haut stationnent en raison
# en raison d un train en panne a cergy prefecture rera
# en raison d une panne electrique a val d europe des bus de remplacement sont a votre disposition la reprise est estimee vers h rera
# actuellement a saint maur creteil et en direction de boissy saint leger stationne en raison
# actuellement entre charles de gaulle etoile et auber et en direction de torcy stationne en raison
# actuellement a noisiel et en direction de saint germain en laye stationne en raison
# actuellement entre auber et chatelet les halles et en direction de boissy saint leger stationne en raison
# en raison d une panne electrique a val d europe reprise estimee a rera le trafic est perturbe entre torcy et saint germain en laye rera
# en raison d un train en panne a val d europe rera
# actuellement a gare de lyon et en direction de saint germain en laye stationne en raison
# en raison d un incident d exploitation a poissy rera
# actuellement a rueil malmaison et en direction de saint germain en laye stationne en raison
# cela fait suite a un accident grave de personne a nanterre ville rera
# en raison d un bagage oublie a la varenne chennevieres rera
# actuellement a gare de lyon et en direction de saint germain en laye stationne en raison
# actuellement a auber et en direction de torcy stationne en raison
# actuellement a torcy et en direction de marne la vallee chessy stationne en raison
# actuellement a la varenne chennevieres et en direction de boissy saint leger stationne en raison
# actuellement a gare de lyon et en direction de la defense stationne en raison
# en raison d un malaise voyageur a houilles carriere
# cela fait suite a un train en panne a maisons laffitte rera
# en raison de difficultes d exploitation a marne la vallee chessy rera
# est perturbe de poissy vers marne la vallee en repercussion d un incident d exploitation a poissy rera
# est perturbe de marne la vallee vers poissy en repercussion d une gene a la fermeture des portes a maison laffitte rera
# en raison d une gene a la fermeture des portes a acheres ville rera
# est perturbe de maisons laffitte vers marne la vallee chessy en raison d un incident d exploitation rera
# en repercussion de personnes sur les voies a acheres grand cormier rera
# actuellement a gare de lyon et en direction de boissy saint leger stationne en raison
# actuellement a acheres grand cormier et en direction de boissy saint leger stationne en raison
# actuellement a noisy le grand mont d est et en direction de marne la vallee chessy stationne en raison
# en raison d un bagage oublie a saint germain en laye rera
# en raison de difficultes d exploitation a boissy saint leger rera
# actuellement a boissy saint leger et en direction de cergy le haut stationne en raison
# actuellement a saint maur creteil et en direction de boissy saint leger stationne en raison
# actuellement a rueil malmaison et en direction de saint germain en laye stationne en raison
# actuellement a noisy champs et en direction de saint germain en laye stationne en raison
# est perturbe de nanterre prefecture vers boissy st leger sur le rera en raison de difficultes d exploitation a poissy
# stationnement est prolonge a chatelet les halles en direction de torcy en raison
# en raison de difficultes d exploitation a la defense rera
# est perturbe de la defense vers boissy st leger rera
# stationnement est prolonge a charles de gaulle etoile en direction de marne la vallee chessy en raison
# en raison de personnes sur les voies a vincennes rera
# en raison d une panne electrique a torcy rera
# est perturbe de torcy vers poissy rera
# en raison d un incident d exploitation a torcy rera
# panne a sartrouville est termine le trafic est retabli de sartrouville vers poissy rera
# en raison d un bagage oublie la gare de saint maur creteil n est pas desservi en direction de boissy saint leger et cergy le haut rera
# en raison d un train en panne a sartrouville rera
# en raison d une panne de signalisation a maisons laffitte rera
# en raison d un incident d exploitation a vincennes rera
# en raison d un incident d exploitation a vincennes rera
# en raison de difficultes d exploitation a neuville universite
# stationnement est prolonge a chatelet les halles en direction de saint germain en laye en raison
# en raison d une gene a la fermeture des portes le stationnement est prolonge a la defense en direction de saint germain en laye rera
# en raison d un incident d exploitation a neuville universite et d une panne de signalisation a nanterre prefecture le trafic est perturbe sur l ensemble du rera
# en raison d un incident technique a la defense rera
# en raison de difficultes d exploitation a torcy rera
# en raison d un incident d exploitation a neuville universite rera
# en raison d un incident d exploitation a neuville universite rera
# actuellement a nanterre prefecture et en direction de marne la vallee chessy stationne en raison
# en raison d un incident d exploitation a neuville universite rera
# actuellement a houilles carrieres sur seine et en direction de boissy saint leger stationne en raison
# actuellement a torcy et en direction de saint germain en laye stationne en raison
# en raison d un incident d exploitation a boissy saint leger rera
# en raison de personnes sur les voies a marne la vallee chessy
# panne a torcy est termine le trafic est retabli de torcy vers saint germain en laye rera
# actuellement a torcy et en direction de saint germain en laye stationne en raison
# actuellement a la defense et en direction de marne la vallee chessy stationne en raison
# actuellement a rueil malmaison et en direction de marne la vallee chessy stationne en raison
# actuellement a nation et en direction de cergy le haut stationne en raison
# actuellement a auber et en direction de marne la vallee chessy stationne en raison
# actuellement a vincennes et en direction de saint germain en laye stationne en raison
# en raison d un train en panne a auber rera
# est perturbe de maisons laffitte vers poissy sur le rera en repercussion d un incident de signalisation a poissy
# est perturbe de maisons laffitte vers poissy sur le rera en repercussion d une panne de signalisation a poissy
# est perturbe de poissy vers marne la vallee chessy sur le rera en raison d un incident de signalisation a poissy
# en raison d un incident affectant la voie a boissy st leger rera
# stationne a nation en direction de saint germain en laye cergy le haut et poissy en raison
# en raison de difficultes d exploitation a cergy le haut et poissy rera
# en raison d un incident voyageur a torcy rera
# stationne a vincennes en direction de poissy en raison
# en raison d une gene a la fermeture des portes a la defense rera
# en raison d un incident technique a torcy rera
# actuellement a vincennes et en direction de marne la vallee chessy stationne en raison
# actuellement a gare de lyon et en direction de boissy saint leger stationne en raison
# actuellement a gare de lyon et en direction de marne la vallee chessy stationne en raison
# actuellement a auber et en direction de marne la vallee chessy stationne en raison

# %%
df_f[(df_f['tweet_type']=='Normal') & (df_f['len_label']>0)].groupby(['gare_source']).size()
# Out:
# gare_source
#                                 18
# Achères Grand Cormier            4
# Achères Ville                   19
# Auber                           44
# Boissy-Saint-Léger              30
# Bry-sur-Marne                   11
# Bussy-Saint-Georges             15
# Cergy le Haut                   35
# Champigny                        6
# Charles de Gaulle-Etoile        20
# Chatou-Croissy                   2
# Châtelet les Halles             46
# Conflans Fin d'Oise              4
# Fontenay-sous-Bois              25
# Gare de Lyon                    44
# Houilles-Carrières-sur-Seine    10
# Joinville-le-Pont                4
# La Défense                      36
# La Varenne-Chennevières         23
# Le Vésinet-Le Pecq               5
# Lognes                           7
# Maisons-Laffitte                17
# Marne-la-Vallée-Chessy          29
# Nanterre Préfecture             60
# Nanterre Université              8
# Nanterre Ville                  11
# Nation                          24
# Neuilly-Plaisance               13
# Neuville Université             11
# Nogent-sur-Marne                 4
# Noisiel                         10
# Noisy-Champs                     3
# Noisy-le-Grand-Mont d'Est       14
# Parc de Saint-Maur               2
# Poissy                          28
# Rueil-Malmaison                 34
# Saint-Germain-en-Laye           13
# Saint-Maur-Créteil               5
# Sartrouville                    10
# Sucy-Bonneuil                   10
# Torcy                           62
# Val d'Europe                    18
# Vincennes                       34
# dtype: int64

# %%
df_f[(df_f['tweet_type']=='Normal') & (df_f['len_label']>0) & (df_f['gare_source']=="Nanterre Préfecture")].content.values
# Out:
# array([" Les trains ne marquent pas l'arrêt en gare de Nanterre\u2006–\u2006Préfecture en direction de Saint-Germain-en-Laye (bagage oublié). #RERA",
#        " Le trafic est perturbé de La Défense vers Cergy-Le Haut • Poissy et Saint-Germain-en-Laye en raison d'un bagage oublié sur le quai à Nanterre\u2006–\u2006Préfecture. #RERA",
#        "Le train actuellement à Nanterre\u2006–\u2006Préfecture et en direction de Poissy stationne en raison d'un incident nécessitant l'intervention des agents. #RERA",
#        "Le train actuellement à Nanterre\u2006–\u2006Préfecture et en direction de Cergy-le Haut stationne en raison de l'actionnement d'un signal d'alarme. #RERA",
#        "Le trafic est ralenti de Nanterre-Préfecture vers Saint-Germain-en-Laye en raison d'un bagage oublié à Nanterre Préfecture #RERA",
#        " Le trafic est perturbé de Nanterre\u2006–\u2006Préfecture vers Boissy-Saint-Léger en raison d'un incident d'exploitation à Nanterre\u2006–\u2006Préfecture. #RERA",
#        "Un train stationne à Nanterre\u2006–\u2006Préfecture en direction de Boissy-Saint-Léger sur le #RERA, en raison d'un incident nécessitant l’intervention de nos agents .",
#        "Le train actuellement à Nanterre\u2006–\u2006Préfecture et en direction de Saint-Germain-en-Laye stationne en raison d'un incident nécessitant l'intervention des agents. #RERA",
#        "  Le trafic est perturbé entre Vincennes et St Germain en Laye / Cergy le Haut / Poissy, en raison d'un bagage oublié sur un quai à Nanterre – Préfecture. #RERA",
#        "Le train actuellement à Nanterre\u2006–\u2006Préfecture et en direction de Poissy stationne en raison d'un bagage oublié dans un train. #RERA",
#        " Le trafic est perturbé de Nanterre–Préfecture vers Cergy–Le Haut en raison d'un train en panne à Nanterre–Préfecture. #RERA",
#        " Le trafic est perturbé de Nanterre Préfecture vers Cergy le Haut en raison d'un incident d'exploitation. #RERA",
#        "Le train actuellement à Nanterre\u2006–\u2006Préfecture et en direction de Marne-la-Vallée–Chessy stationne en raison de l'actionnement d'un signal d'alarme. #RERA",
#        "Le train actuellement à Nanterre\u2006–\u2006Préfecture et en direction de Poissy stationne en raison de l'intervention du conducteur. #RERA",
#        "Le train actuellement à Nanterre\u2006–\u2006Préfecture et en direction de Poissy stationne en raison d'un incident nécessitant l'intervention des agents. #RERA",
#        "Le trafic est perturbé de Nanterre-Préfecture vers Poissy en raison d'une panne d'une portes de train à Nanterre-Préfecture. #RERA",
#        " Le trafic est perturbé de Nanterre\u2006–\u2006Préfecture vers Boissy-Saint-Léger en raison de la panne d'un train à Nanterre\u2006–\u2006Préfecture. #RERA",
#        "Le train actuellement à Nanterre–Préfecture et en direction de Cergy–Le Haut stationne en raison de difficultés d'exploitation. #RERA",
#        " Le trafic est perturbé de Rueil Malmaison vers Boissy Saint Léger, en raison d'un malaise voyageur à Nanterre – Préfecture. #RERA",
#        "Le train actuellement entre Nanterre\u2006–\u2006Préfecture et La Défense et en direction de Marne-la-Vallée–Chessy stationne en raison d'un inc
RERA",
#        "Le train actuellement à Nanterre\u2006–\u2006Préfecture et en direction de Cergy-Le Haut stationne en raison d'un incident nécessitant l'intervention des agents. #RERA",
#        "Le trafic est perturbé de Nanterre-Préfecture vers Boissy-St-leger sur le #RERA en raison de difficultés d'exploitation à Poissy.",
#        "En raison d'une panne de signalisation à Nanterre – Préfecture, le trafic est perturbé sur l'ensemble du #RERA",
#        "Le train actuellement à Nanterre\u2006–\u2006Préfecture et en direction de Marne-la-Vallée–Chessy stationne en raison d'un incident technique. #RERA"],
#       dtype=object)

# %%
df_f[(df_f['tweet_type']=='Normal') & (df_f['len_label']>0) & (df_f['nb_gare_detected']>1) & (df_f['gare_source']=="")][['content', 'content_cleaned']].values
# Out:
# array([[' Le trafic est interrompu entre Nation et Val de Fontenay, et entre Fontenay-sous-Bois et Nation (train en panne). Reprise estimée : 06:00. #RERA',
#         ' le trafic est interrompu entre nation et val de fontenay et entre fontenay sous bois et nation train en panne reprise estimee rera'],
#        [' Le trafic est interrompu entre Houilles Carrières-sur-Seine et Nanterre -Préfecture et perturbé sur le reste de la ligne (accident grave de personne). Reprise estimée : 07:30. #RERA',
#         ' le trafic est interrompu entre houilles carrieres sur seine et nanterre prefecture et perturbe sur le reste de la ligne accident grave de personne reprise estimee rera'],
#        ["Le trafic est interrompu entre Achères Ville et Maisons-Laffite en raison d'une chute de caténaire. La reprise est estimée vers 07h00. Le trafic est très perturbé sur le reste de la ligne. #RERA",
#         'le trafic est interrompu entre acheres ville et maisons laffite en raison d une chute de catenaire la reprise est estimee vers h le trafic est tres perturbe sur le reste de la ligne rera'],
#        [" Le trafic est perturbé du Parc Saint - Maur vers Boissy-Saint-Léger en raison d'un incident voyageur au Parc Saint - Maur. #RERA",
#         ' le trafic est perturbe du parc saint maur vers boissy saint leger en raison d un incident voyageur au parc saint maur rera'],
#        [" Le trafic est perturbé entre St-Germain-En-Laye et Marne-la-Vallée-Chessy en raison d'une rupture de caténaire. #RERA",
#         ' le trafic est perturbe entre st germain en laye et marne la vallee chessy en raison d une rupture de catenaire rera'],
#        ["  Le trafic est interrompu entre Poissy et Maisons-Laffitte et perturbé sur le reste de la ligne, en raison d'une panne de train. Reprise estimée à 18:30 #RERA",
#         ' le trafic est interrompu entre poissy et maisons laffitte et perturbe sur le reste de la ligne en raison d une panne de train reprise estimee a rera'],
#        [' Le trafic est rétabli entre Cergy-Le Haut • Poissy et Nanterre-Préfecture (panne électrique). #RERA',
#         ' le trafic est retabli entre cergy le haut poissy et nanterre prefecture panne electrique rera'],
#        ["Le trafic est interrompu entre Saint Germain en Laye et Nanterre Préfecture en raison d'une fin tardive de chantier. Le trafic reprendra vers 05h30. #RERA",
#         'le trafic est interrompu entre saint germain en laye et nanterre prefecture en raison d une fin tardive de chantier le trafic reprendra vers h rera'],
#        ["le trafic est perturbé entre Nanterre-Préfecture et Poissy sur le #RERA, en raison d'un incident affectant la voie à Poissy.",
#         'le trafic est perturbe entre nanterre prefecture et poissy sur le rera en raison d un incident affectant la voie a poissy '],
#        [" Le trafic reprend progressivement entre Nation et Auber mais reste très perturbé sur l'ensemble de la ligne (bagage oublié). #RERA",
#         ' le trafic reprend progressivement entre nation et auber mais reste tres perturbe sur l ensemble de la ligne bagage oublie rera'],
#        ["  Le trafic est interrompu de Fontenay-sous-Bois • Val de Fontenay vers Auber, en raison d'un bagage oublié. Reprise estimée à 17:00. #RERA",
#         ' le trafic est interrompu de fontenay sous bois val de fontenay vers auber en raison d un bagage oublie reprise estimee a rera'],
#        [" Le trafic est interrompu entre Maison Laffite et Poissy et reprendra vers 00h00. Cela fait suite à des difficultés d'exploitation #RERA",
#         ' le trafic est interrompu entre maison laffite et poissy et reprendra vers h cela fait suite a des difficultes d exploitation rera']],
#       dtype=object)

# %% [markdown]
# ## Visualisation finale

# %% [markdown]
# ### Nombre d'incidents par mois

# %%
df_f
# Out:
#      tweet_type          time_posted  \
# 0        Normal  2024-10-23 15:05:16
# 1       Réponse  2024-10-23 15:16:44
# 2        Normal  2024-10-23 13:47:35
# 3       Réponse  2024-10-23 13:52:44
# 4       Réponse  2024-10-23 14:08:50
# ...         ...                  ...
# 2720    Réponse  2024-05-28 07:37:53
# 2721     Normal  2024-05-28 07:19:10
# 2722    Réponse  2024-05-28 07:22:19
# 2723     Normal  2024-05-28 05:55:27
# 2724    Réponse  2024-05-28 06:00:21
#
#                                                 content  \
# 0      Le trafic est perturbé de Nanterre–Préfecture...
# 1              Citation du tweet du 2024-10-23 15:14:09
# 2     Le train actuellement à Noisy-Champs et en dir...
# 3      Le trafic est interrompu entre Noisy-le-Grand...
# 4                                                   nan
# ...                                                 ...
# 2720  Fin de stationnement à Marne-la-Vallée–Chessy....
# 2721  Le train actuellement à Val d'Europe et en dir...
# 2722  Fin de stationnement à Val d'Europe. Le train ...
# 2723  Le train actuellement à Boissy-Saint-Léger et ...
# 2724  Fin de stationnement à Boissy-Saint-Léger. Le ...
#
#                                  thread_id  comments  retweets  likes  \
# 0     3d60d6de-2f77-4d95-86dd-c0eb73e2e61f         4         1     10
# 1     3d60d6de-2f77-4d95-86dd-c0eb73e2e61f         0         0      0
# 2     9d7d231b-fea1-4ec8-8567-2b350c63dc39        15        50    232
# 3     9d7d231b-fea1-4ec8-8567-2b350c63dc39        18         6     38
# 4     9d7d231b-fea1-4ec8-8567-2b350c63dc39         0         0      6
# ...                                    ...       ...       ...    ...
# 2720  dcda4c45-e19e-4d70-948d-a02d90893da1         0         0      0
# 2721  8fd57892-fb2a-4fcf-8cb0-9e3ae9dfbf93         1         0      3
# 2722  8fd57892-fb2a-4fcf-8cb0-9e3ae9dfbf93         0         0      3
# 2723  e3047823-46ab-4296-be32-531622e90d3c         5         1      4
# 2724  e3047823-46ab-4296-be32-531622e90d3c         0         0      1
#
#         views             extraction_date  \
# 0       18730  2024-12-01 12:15:55.319256
# 1       13294  2024-12-01 12:16:09.052328
# 2     2525453  2024-12-01 12:16:30.388911
# 3       46540  2024-12-01 12:16:40.942384
# 4       41248  2024-12-01 12:16:41.167656
# ...       ...                         ...
# 2720     3378  2024-12-03 17:51:04.535912
# 2721     5263  2024-12-03 17:51:17.771893
# 2722     3572  2024-12-03 17:51:29.927111
# 2723    10027  2024-12-03 17:51:40.177002
# 2724     6222  2024-12-03 17:51:52.348447
#
#                                         content_cleaned  ... nb_gare_detected  \
# 0      le trafic est perturbe de nanterre prefecture...  ...                3
# 1                                 citation du tweet du   ...                1
# 2     le train actuellement a noisy champs et en dir...  ...                2
# 3      le trafic est interrompu entre noisy le grand...  ...                2
# 4                                                   nan  ...                1
# ...                                                 ...  ...              ...
# 2720  fin de stationnement a marne la vallee chessy ...  ...                2
# 2721  le train actuellement a val d europe et en dir...  ...                2
# 2722  fin de stationnement a val d europe le train r...  ...                2
# 2723  le train actuellement a boissy saint leger et ...  ...                2
# 2724  fin de stationnement a boissy saint leger le t...  ...                2
#
#                                    content_removed_gare  \
# 0      le trafic est perturbe de  vers  en repercuss...
# 1                                 citation du tweet du
# 2     le train actuellement a  et en direction de  s...
# 3      le trafic est interrompu entre  et  et pertur...
# 4                                                   nan
# ...                                                 ...
# 2720  fin de stationnement a  le train repart en dir...
# 2721  le train actuellement a  et en direction de  s...
# 2722  fin de stationnement a  le train repart en dir...
# 2723  le train actuellement a  et en direction de  s...
# 2724  fin de stationnement a  le train repart en dir...
#
#                        content_removed_sw              content_cleand_str  \
# 0       [presence, obstacle, pres, voies]    presence obstacle pres voies
# 1                       [citation, tweet]                  citation tweet
# 2       [presence, obstacle, pres, voies]    presence obstacle pres voies
# 3       [presence, obstacle, pres, voies]    presence obstacle pres voies
# 4                                   [nan]                             nan
# ...                                   ...                             ...
# 2720             [fin, panne, electrique]            fin panne electrique
# 2721                [mesures, regulation]              mesures regulation
# 2722           [fin, mesures, regulation]          fin mesures regulation
# 2723       [actionnement, signal, alarme]      actionnement signal alarme
# 2724  [fin, actionnement, signal, alarme]  fin actionnement signal alarme
#
#                                             word_counts  \
# 0     {'presence': 1, 'obstacle': 1, 'pres': 1, 'voi...
# 1                           {'citation': 1, 'tweet': 1}
# 2     {'presence': 1, 'obstacle': 1, 'pres': 1, 'voi...
# 3     {'presence': 1, 'obstacle': 1, 'pres': 1, 'voi...
# 4                                            {'nan': 1}
# ...                                                 ...
# 2720            {'fin': 1, 'panne': 1, 'electrique': 1}
# 2721                    {'mesures': 1, 'regulation': 1}
# 2722          {'fin': 1, 'mesures': 1, 'regulation': 1}
# 2723      {'actionnement': 1, 'signal': 1, 'alarme': 1}
# 2724  {'fin': 1, 'actionnement': 1, 'signal': 1, 'al...
#
#                                           bigram_counts  \
# 0     {('presence', 'obstacle'): 1, ('obstacle', 'pr...
# 1                            {('citation', 'tweet'): 1}
# 2     {('presence', 'obstacle'): 1, ('obstacle', 'pr...
# 3     {('presence', 'obstacle'): 1, ('obstacle', 'pr...
# 4                                                    {}
# ...                                                 ...
# 2720  {('fin', 'panne'): 1, ('panne', 'electrique'): 1}
# 2721                     {('mesures', 'regulation'): 1}
# 2722  {('fin', 'mesures'): 1, ('mesures', 'regulatio...
# 2723  {('actionnement', 'signal'): 1, ('signal', 'al...
# 2724  {('fin', 'actionnement'): 1, ('actionnement', ...
#
#                                          trigram_counts is_problem  \
# 0     {('presence', 'obstacle', 'pres'): 1, ('obstac...       True
# 1                                                    {}       True
# 2     {('presence', 'obstacle', 'pres'): 1, ('obstac...       True
# 3     {('presence', 'obstacle', 'pres'): 1, ('obstac...       True
# 4                                                    {}       True
# ...                                                 ...        ...
# 2720                {('fin', 'panne', 'electrique'): 1}       True
# 2721                                                 {}       True
# 2722              {('fin', 'mesures', 'regulation'): 1}       True
# 2723          {('actionnement', 'signal', 'alarme'): 1}       True
# 2724  {('fin', 'actionnement', 'signal'): 1, ('actio...       True
#
#                     date engagement
# 0    2024-10-23 15:05:16   0.080085
# 1    2024-10-23 15:16:44   0.000000
# 2    2024-10-23 13:47:35   0.011760
# 3    2024-10-23 13:52:44   0.133219
# 4    2024-10-23 14:08:50   0.014546
# ...                  ...        ...
# 2720 2024-05-28 07:37:53   0.000000
# 2721 2024-05-28 07:19:10   0.076002
# 2722 2024-05-28 07:22:19   0.083987
# 2723 2024-05-28 05:55:27   0.099731
# 2724 2024-05-28 06:00:21   0.016072
#
# [2716 rows x 21 columns]

# %%
incident_notifies = df_f[(df_f['tweet_type']=='Normal') & (df_f['len_label']>0)]
incident_notifies['date'] = pd.to_datetime(incident_notifies['time_posted'])

incident_par_mois = incident_notifies.groupby(incident_notifies['date'].dt.to_period('M')).size()
incident_par_jour = incident_notifies.groupby(incident_notifies['date'].dt.to_period('D')).size()

tweets_per_day_label = incident_notifies.groupby([incident_notifies['date'].dt.to_period('D'), 'label']).size().unstack(fill_value=0)
tweets_per_day_label.index = tweets_per_day_label.index.to_timestamp()

total_tweets_per_label = tweets_per_day_label.sum()
# Sélectionner les labels les plus nombreux (par exemple, les 5 premiers)
top_labels = total_tweets_per_label.nlargest(1).index


incident_par_mois.index = incident_par_mois.index.to_timestamp()
incident_par_jour.index = incident_par_jour.index.to_timestamp()
# Out:
# C:\Users\gabriel\AppData\Local\Temp\ipykernel_4364\3074638833.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   incident_notifies['date'] = pd.to_datetime(incident_notifies['time_posted'])

# %%
fig, ax = plt.subplots(
    figsize=(30, 10)
)

ax.plot(incident_par_jour.index, incident_par_jour.values, label="Nombre d'incidents quotidiens", linewidth=2)

for label in top_labels:
    ax.plot(tweets_per_day_label.index, tweets_per_day_label[label], label=label)


ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.spines["top"].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position("left")
ax.xaxis.set_ticks_position("bottom")
#ax.spines["bottom"].set_bounds(min(incident_par_jour.index), max(incident_par_jour.index))

ax.set_xlabel("Date")
ax.set_ylabel("Nombre d'incidents")
plt.legend()
plt.show()

# %%
# Créer une figure et un axe
fig, ax = plt.subplots(figsize=(30, 10))

# Tracer les données pour chaque label parmi les plus nombreux
for label in top_labels:
    ax.plot(tweets_per_day_label.index, tweets_per_day_label[label], label=label)

# Ajouter des labels et une légende
ax.set_xlabel('Date')
ax.set_ylabel('Nombre de tweets')
ax.legend(title='Label')

# Afficher la figure
plt.show()

# %% [markdown]
# ### Temps de résolutinon

# %%
tweet_incidents = df_f[df_f['is_problem']==True]
tweet_normaux_incidents = tweet_incidents[tweet_incidents['tweet_type']=='Normal']

# %%
tweet_normaux_incidents['date'] = pd.to_datetime(tweet_normaux_incidents['time_posted'])

# Compter le nombre de tweets normaux incidents par jour
tweets_normaux_incidents_per_day = tweet_normaux_incidents.set_index('date').resample('D').size()

# Afficher le nombre de tweets normaux incidents par jour
plt.figure(figsize=(12, 6))
tweets_normaux_incidents_per_day.plot()
plt.title('Nombre de tweets normaux incidents par jour')
plt.xlabel('Date')
plt.ylabel('Nombre de tweets')
plt.show()
# Out:
# C:\Users\gabriel\AppData\Local\Temp\ipykernel_4364\3611408497.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweet_normaux_incidents['date'] = pd.to_datetime(tweet_normaux_incidents['time_posted'])

# %%
unique_id = tweet_incidents['tweet_id'].unique()
len(unique_id)
# Out:
# 828

# %%
pb_resolve = {
    'id': [],
    'begin_date': [],
    'end_date': [],
    'duration': []
}
for id in unique_id:


    
    df_id = df_f[df_f['tweet_id']==id]

    begin_date = df_id[df_id['tweet_type']=='Normal']['date'].values[0]

    try:
        end_date = df_id[df_id['tweet_type']=='Réponse'].sort_values('date', ascending=False).iloc[0]['date']
    except Exception:
        continue

    pb_resolve['id'].append(id)
    pb_resolve['begin_date'].append(begin_date)
    pb_resolve['end_date'].append(end_date)
    pb_resolve['duration'].append(end_date - begin_date)

# %%
pb_resolve_df = pd.DataFrame.from_dict(pb_resolve)
pb_resolve_df.iloc[pb_resolve_df['duration'].idxmax()]
# Out:
# id            2c1ab6ce-f8b0-49e8-a146-73191cd37267
# begin_date                     2024-06-17 10:47:51
# end_date                       2024-06-18 04:21:29
# duration                           0 days 17:33:38
# Name: 286, dtype: object

# %%
pb_resolve_df['duration'].describe()
# Out:
# count                          768
# mean     0 days 00:40:58.902343750
# std      0 days 01:08:38.499840755
# min                0 days 00:00:00
# 25%         0 days 00:03:18.750000
# 50%                0 days 00:13:21
# 75%         0 days 00:56:52.500000
# max                0 days 17:33:38
# Name: duration, dtype: object

# %%
Q1 = pb_resolve_df['duration'].quantile(0.25)
Q3 = pb_resolve_df['duration'].quantile(0.75)
IQR = Q3 - Q1

# Définir les limites pour les outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filtrer les données pour éliminer les outliers
filtered_df = pb_resolve_df[(pb_resolve_df['duration'] >= lower_bound) & (pb_resolve_df['duration'] <= upper_bound)]

# %%
# Ajouter une colonne pour le mois
filtered_df['month'] = filtered_df['begin_date'].dt.to_period('M')

# Calculer la durée moyenne par mois
average_duration_per_month = filtered_df.groupby('month')['duration'].mean()

# Tracer les données
plt.figure(figsize=(12, 6))
average_duration_per_month.plot(kind='bar', color='skyblue')

# Ajouter des titres et des étiquettes
plt.title('Durée moyenne de résolution par mois')
plt.xlabel('Mois')
plt.ylabel('Durée moyenne de résolution')

# Afficher le graphique
plt.show()
# Out:
# C:\Users\gabriel\AppData\Local\Temp\ipykernel_4364\1301411404.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['month'] = filtered_df['begin_date'].dt.to_period('M')
